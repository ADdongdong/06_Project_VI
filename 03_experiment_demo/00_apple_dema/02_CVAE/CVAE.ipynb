# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import DataLoader
import utils


class CVAE(nn.Module):
    """Implementation of CVAE(Conditional Variational Auto-Encoder)"""
    def __init__(self, feature_size, class_size, latent_size):
        super(CVAE, self).__init__()

        self.fc1 = nn.Linear(feature_size + class_size, 200)
        self.fc2_mu = nn.Linear(200, latent_size)
        self.fc2_log_std = nn.Linear(200, latent_size)
        self.fc3 = nn.Linear(latent_size + class_size, 200)
        self.fc4 = nn.Linear(200, feature_size)

    def encode(self, x, y):
        h1 = F.relu(self.fc1(torch.cat([x, y], dim=1)))  # concat features and labels
        mu = self.fc2_mu(h1)
        log_std = self.fc2_log_std(h1)
        return mu, log_std

    def decode(self, z, y):
        h3 = F.relu(self.fc3(torch.cat([z, y], dim=1)))  # concat latents and labels
        recon = torch.sigmoid(self.fc4(h3))  # use sigmoid because the input image's pixel is between 0-1
        return recon

    def reparametrize(self, mu, log_std):
        std = torch.exp(log_std)
        eps = torch.randn_like(std)  # simple from standard normal distribution
        z = mu + eps * std
        return z

    def forward(self, x, y):
        mu, log_std = self.encode(x, y)
        z = self.reparametrize(mu, log_std)
        recon = self.decode(z, y)
        return recon, mu, log_std

    def loss_function(self, recon, x, mu, log_std) -> torch.Tensor:
        recon_loss = F.mse_loss(recon, x, reduction="sum")  # use "mean" may have a bad effect on gradients
        kl_loss = -0.5 * (1 + 2*log_std - mu.pow(2) - torch.exp(2*log_std))
        kl_loss = torch.sum(kl_loss)
        loss = recon_loss + kl_loss
        return loss


if __name__ == '__main__':
    epochs = 100
    batch_size = 100

    recon = None
    img = None

    utils.make_dir("./img/cvae")
    utils.make_dir("./model_weights/cvae")

    train_data = torchvision.datasets.MNIST(
        root='./mnist',
        train=True,
        transform=torchvision.transforms.ToTensor(),
        download=True
    )

    data_loader = DataLoader(train_data, batch_size=100, shuffle=True)

    cvae = CVAE(feature_size=784, class_size=10, latent_size=10)

    optimizer = torch.optim.Adam(cvae.parameters(), lr=1e-3)

    for epoch in range(100):
        train_loss = 0
        i = 0
        for batch_id, data in enumerate(data_loader):
            img, label = data
            inputs = img.reshape(img.shape[0], -1)
            y = utils.to_one_hot(label.reshape(-1, 1), num_class=10)
            recon, mu, log_std = cvae(inputs, y)
            loss = cvae.loss_function(recon, inputs, mu, log_std)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            i += 1

            if batch_id % 100 == 0:
                print("Epoch[{}/{}], Batch[{}/{}], batch_loss:{:.6f}".format(
                    epoch+1, epochs, batch_id+1, len(data_loader), loss.item()))

        print("======>epoch:{},\t epoch_average_batch_loss:{:.6f}============".format(epoch+1, train_loss/i), "\n")

        # save imgs
        if epoch % 10 == 0:
            imgs = utils.to_img(recon.detach())
            path = "./img/cvae/epoch{}.png".format(epoch+1)
            torchvision.utils.save_image(imgs, path, nrow=10)
            print("save:", path, "\n")

    torchvision.utils.save_image(img, "./img/cvae/raw.png", nrow=10)
    print("save raw image:./img/cvae/raw/png", "\n")

    # save val model
    utils.save_model(cvae, "./model_weights/cvae/cvae_weights.pth")
# Out:
# Epoch[1/100], Batch[1/600], batch_loss:18380.478516
# Epoch[1/100], Batch[101/600], batch_loss:5247.502441
# Epoch[1/100], Batch[201/600], batch_loss:4193.456543
# Epoch[1/100], Batch[301/600], batch_loss:4127.814941
# Epoch[1/100], Batch[401/600], batch_loss:3824.768066
# Epoch[1/100], Batch[501/600], batch_loss:3669.165771
# ======>epoch:1,	 epoch_average_batch_loss:4525.299221============
#
# save: ./img/cvae/epoch1.png
#
# Epoch[2/100], Batch[1/600], batch_loss:3512.595947
# Epoch[2/100], Batch[101/600], batch_loss:3260.130371
# Epoch[2/100], Batch[201/600], batch_loss:3300.357910
# Epoch[2/100], Batch[301/600], batch_loss:3407.264648
# Epoch[2/100], Batch[401/600], batch_loss:3209.415039
# Epoch[2/100], Batch[501/600], batch_loss:3075.666504
# ======>epoch:2,	 epoch_average_batch_loss:3284.281906============
#
# Epoch[3/100], Batch[1/600], batch_loss:3252.770020
# Epoch[3/100], Batch[101/600], batch_loss:3172.850830
# Epoch[3/100], Batch[201/600], batch_loss:3292.531494
# Epoch[3/100], Batch[301/600], batch_loss:3039.009766
# Epoch[3/100], Batch[401/600], batch_loss:3052.557617
# Epoch[3/100], Batch[501/600], batch_loss:2951.335205
# ======>epoch:3,	 epoch_average_batch_loss:3073.540334============
#
# Epoch[4/100], Batch[1/600], batch_loss:2953.861816
# Epoch[4/100], Batch[101/600], batch_loss:3013.074219
# Epoch[4/100], Batch[201/600], batch_loss:2919.868896
# Epoch[4/100], Batch[301/600], batch_loss:3040.160400
# Epoch[4/100], Batch[401/600], batch_loss:2797.637207
# Epoch[4/100], Batch[501/600], batch_loss:2920.676514
# ======>epoch:4,	 epoch_average_batch_loss:2961.802202============
#
# Epoch[5/100], Batch[1/600], batch_loss:2857.359375
# Epoch[5/100], Batch[101/600], batch_loss:2911.214844
# Epoch[5/100], Batch[201/600], batch_loss:2972.710449
# Epoch[5/100], Batch[301/600], batch_loss:2790.120605
# Epoch[5/100], Batch[401/600], batch_loss:2739.779297
# Epoch[5/100], Batch[501/600], batch_loss:2743.296387
# ======>epoch:5,	 epoch_average_batch_loss:2889.311933============
#
# Epoch[6/100], Batch[1/600], batch_loss:2863.945312
# Epoch[6/100], Batch[101/600], batch_loss:2906.111084
# Epoch[6/100], Batch[201/600], batch_loss:2891.327148
# Epoch[6/100], Batch[301/600], batch_loss:2880.648682
# Epoch[6/100], Batch[401/600], batch_loss:2701.839600
# Epoch[6/100], Batch[501/600], batch_loss:2783.599609
# ======>epoch:6,	 epoch_average_batch_loss:2841.463333============
#
# Epoch[7/100], Batch[1/600], batch_loss:2867.841553
# Epoch[7/100], Batch[101/600], batch_loss:2804.490723
# Epoch[7/100], Batch[201/600], batch_loss:2930.881348
# Epoch[7/100], Batch[301/600], batch_loss:2879.864990
# Epoch[7/100], Batch[401/600], batch_loss:2859.179199
# Epoch[7/100], Batch[501/600], batch_loss:2821.204834
# ======>epoch:7,	 epoch_average_batch_loss:2803.826961============
#
# Epoch[8/100], Batch[1/600], batch_loss:2760.241455
# Epoch[8/100], Batch[101/600], batch_loss:2908.624023
# Epoch[8/100], Batch[201/600], batch_loss:2827.306152
# Epoch[8/100], Batch[301/600], batch_loss:2799.400146
# Epoch[8/100], Batch[401/600], batch_loss:2695.244141
# Epoch[8/100], Batch[501/600], batch_loss:2837.491211
# ======>epoch:8,	 epoch_average_batch_loss:2775.254713============
#
# Epoch[9/100], Batch[1/600], batch_loss:2694.510010
# Epoch[9/100], Batch[101/600], batch_loss:2678.620850
# Epoch[9/100], Batch[201/600], batch_loss:2778.455078
# Epoch[9/100], Batch[301/600], batch_loss:2660.022705
# Epoch[9/100], Batch[401/600], batch_loss:2689.027588
# Epoch[9/100], Batch[501/600], batch_loss:2864.274658
# ======>epoch:9,	 epoch_average_batch_loss:2753.362545============
#
# Epoch[10/100], Batch[1/600], batch_loss:2940.572021
# Epoch[10/100], Batch[101/600], batch_loss:2764.296875
# Epoch[10/100], Batch[201/600], batch_loss:2776.198975
# Epoch[10/100], Batch[301/600], batch_loss:2648.065430
# Epoch[10/100], Batch[401/600], batch_loss:2683.244629
# Epoch[10/100], Batch[501/600], batch_loss:2828.184082
# ======>epoch:10,	 epoch_average_batch_loss:2735.206322============
#
# Epoch[11/100], Batch[1/600], batch_loss:2772.544189
# Epoch[11/100], Batch[101/600], batch_loss:2816.545410
# Epoch[11/100], Batch[201/600], batch_loss:2714.988281
# Epoch[11/100], Batch[301/600], batch_loss:2605.732422
# Epoch[11/100], Batch[401/600], batch_loss:2736.989014
# Epoch[11/100], Batch[501/600], batch_loss:2548.943604
# ======>epoch:11,	 epoch_average_batch_loss:2716.400007============
#
# save: ./img/cvae/epoch11.png
#
# Epoch[12/100], Batch[1/600], batch_loss:2661.281494
# Epoch[12/100], Batch[101/600], batch_loss:2645.281006
# Epoch[12/100], Batch[201/600], batch_loss:2726.088379
# Epoch[12/100], Batch[301/600], batch_loss:2845.945312
# Epoch[12/100], Batch[401/600], batch_loss:2726.874512
# Epoch[12/100], Batch[501/600], batch_loss:2712.701172
# ======>epoch:12,	 epoch_average_batch_loss:2701.994451============
#
# Epoch[13/100], Batch[1/600], batch_loss:2564.236328
# Epoch[13/100], Batch[101/600], batch_loss:2684.777344
# Epoch[13/100], Batch[201/600], batch_loss:2675.883057
# Epoch[13/100], Batch[301/600], batch_loss:2883.721680
# Epoch[13/100], Batch[401/600], batch_loss:2467.593262
# Epoch[13/100], Batch[501/600], batch_loss:2614.531738
# ======>epoch:13,	 epoch_average_batch_loss:2690.925551============
#
# Epoch[14/100], Batch[1/600], batch_loss:2656.268311
# Epoch[14/100], Batch[101/600], batch_loss:2577.969238
# Epoch[14/100], Batch[201/600], batch_loss:2917.481934
# Epoch[14/100], Batch[301/600], batch_loss:2743.860596
# Epoch[14/100], Batch[401/600], batch_loss:2625.075195
# Epoch[14/100], Batch[501/600], batch_loss:2781.594238
# ======>epoch:14,	 epoch_average_batch_loss:2679.618506============
#
# Epoch[15/100], Batch[1/600], batch_loss:2515.812500
# Epoch[15/100], Batch[101/600], batch_loss:2455.110596
# Epoch[15/100], Batch[201/600], batch_loss:2681.346680
# Epoch[15/100], Batch[301/600], batch_loss:2574.843018
# Epoch[15/100], Batch[401/600], batch_loss:2656.268799
# Epoch[15/100], Batch[501/600], batch_loss:2805.863281
# ======>epoch:15,	 epoch_average_batch_loss:2668.137611============
#
# Epoch[16/100], Batch[1/600], batch_loss:2777.253906
# Epoch[16/100], Batch[101/600], batch_loss:2627.656494
# Epoch[16/100], Batch[201/600], batch_loss:2615.463135
# Epoch[16/100], Batch[301/600], batch_loss:2640.673828
# Epoch[16/100], Batch[401/600], batch_loss:2802.862549
# Epoch[16/100], Batch[501/600], batch_loss:2706.151123
# ======>epoch:16,	 epoch_average_batch_loss:2660.943370============
#
# Epoch[17/100], Batch[1/600], batch_loss:2536.013672
# Epoch[17/100], Batch[101/600], batch_loss:2766.478271
# Epoch[17/100], Batch[201/600], batch_loss:2629.160889
# Epoch[17/100], Batch[301/600], batch_loss:2676.642090
# Epoch[17/100], Batch[401/600], batch_loss:2550.890869
# Epoch[17/100], Batch[501/600], batch_loss:2742.844482
# ======>epoch:17,	 epoch_average_batch_loss:2651.897256============
#
# Epoch[18/100], Batch[1/600], batch_loss:2679.767822
# Epoch[18/100], Batch[101/600], batch_loss:2603.094238
# Epoch[18/100], Batch[201/600], batch_loss:2672.207275
# Epoch[18/100], Batch[301/600], batch_loss:2789.802246
# Epoch[18/100], Batch[401/600], batch_loss:2753.024414
# Epoch[18/100], Batch[501/600], batch_loss:2633.861084
# ======>epoch:18,	 epoch_average_batch_loss:2644.675392============
#
# Epoch[19/100], Batch[1/600], batch_loss:2597.491211
# Epoch[19/100], Batch[101/600], batch_loss:2753.056885
# Epoch[19/100], Batch[201/600], batch_loss:2497.077637
# Epoch[19/100], Batch[301/600], batch_loss:2720.739258
# Epoch[19/100], Batch[401/600], batch_loss:2647.461914
# Epoch[19/100], Batch[501/600], batch_loss:2444.176270
# ======>epoch:19,	 epoch_average_batch_loss:2638.413678============
#
# Epoch[20/100], Batch[1/600], batch_loss:2666.547852
# Epoch[20/100], Batch[101/600], batch_loss:2826.917969
# Epoch[20/100], Batch[201/600], batch_loss:2534.938965
# Epoch[20/100], Batch[301/600], batch_loss:2580.622803
# Epoch[20/100], Batch[401/600], batch_loss:2485.353516
# Epoch[20/100], Batch[501/600], batch_loss:2523.215332
# ======>epoch:20,	 epoch_average_batch_loss:2632.455060============
#
# Epoch[21/100], Batch[1/600], batch_loss:2560.312988
# Epoch[21/100], Batch[101/600], batch_loss:2734.873779
# Epoch[21/100], Batch[201/600], batch_loss:2574.788574
# Epoch[21/100], Batch[301/600], batch_loss:2609.193604
# Epoch[21/100], Batch[401/600], batch_loss:2510.134277
# Epoch[21/100], Batch[501/600], batch_loss:2803.175049
# ======>epoch:21,	 epoch_average_batch_loss:2625.817343============
#
# save: ./img/cvae/epoch21.png
#
# Epoch[22/100], Batch[1/600], batch_loss:2612.229980
# Epoch[22/100], Batch[101/600], batch_loss:2735.825684
# Epoch[22/100], Batch[201/600], batch_loss:2616.621338
# Epoch[22/100], Batch[301/600], batch_loss:2459.643555
# Epoch[22/100], Batch[401/600], batch_loss:2712.613037
# Epoch[22/100], Batch[501/600], batch_loss:2787.252686
# ======>epoch:22,	 epoch_average_batch_loss:2620.475973============
#
# Epoch[23/100], Batch[1/600], batch_loss:2695.702393
# Epoch[23/100], Batch[101/600], batch_loss:2636.041504
# Epoch[23/100], Batch[201/600], batch_loss:2710.577637
# Epoch[23/100], Batch[301/600], batch_loss:2540.303711
# Epoch[23/100], Batch[401/600], batch_loss:2541.998535
# Epoch[23/100], Batch[501/600], batch_loss:2678.930176
# ======>epoch:23,	 epoch_average_batch_loss:2615.414921============
#
# Epoch[24/100], Batch[1/600], batch_loss:2637.967529
# Epoch[24/100], Batch[101/600], batch_loss:2597.412598
# Epoch[24/100], Batch[201/600], batch_loss:2582.968262
# Epoch[24/100], Batch[301/600], batch_loss:2642.592285
# Epoch[24/100], Batch[401/600], batch_loss:2692.199463
# Epoch[24/100], Batch[501/600], batch_loss:2542.685059
# ======>epoch:24,	 epoch_average_batch_loss:2610.981958============
#
# Epoch[25/100], Batch[1/600], batch_loss:2718.856934
# Epoch[25/100], Batch[101/600], batch_loss:2511.145020
# Epoch[25/100], Batch[201/600], batch_loss:2690.432129
# Epoch[25/100], Batch[301/600], batch_loss:2563.390869
# Epoch[25/100], Batch[401/600], batch_loss:2788.152344
# Epoch[25/100], Batch[501/600], batch_loss:2590.285889
# ======>epoch:25,	 epoch_average_batch_loss:2605.931486============
#
# Epoch[26/100], Batch[1/600], batch_loss:2556.974365
# Epoch[26/100], Batch[101/600], batch_loss:2648.062012
# Epoch[26/100], Batch[201/600], batch_loss:2572.677490
# Epoch[26/100], Batch[301/600], batch_loss:2572.660400
# Epoch[26/100], Batch[401/600], batch_loss:2668.754150
# Epoch[26/100], Batch[501/600], batch_loss:2609.313721
# ======>epoch:26,	 epoch_average_batch_loss:2603.604601============
#
# Epoch[27/100], Batch[1/600], batch_loss:2551.152344
# Epoch[27/100], Batch[101/600], batch_loss:2654.738281
# Epoch[27/100], Batch[201/600], batch_loss:2554.394531
# Epoch[27/100], Batch[301/600], batch_loss:2568.066895
# Epoch[27/100], Batch[401/600], batch_loss:2586.998535
# Epoch[27/100], Batch[501/600], batch_loss:2535.199219
# ======>epoch:27,	 epoch_average_batch_loss:2595.764646============
#
# Epoch[28/100], Batch[1/600], batch_loss:2558.845215
# Epoch[28/100], Batch[101/600], batch_loss:2659.620117
# Epoch[28/100], Batch[201/600], batch_loss:2524.962891
# Epoch[28/100], Batch[301/600], batch_loss:2537.558838
# Epoch[28/100], Batch[401/600], batch_loss:2583.686523
# Epoch[28/100], Batch[501/600], batch_loss:2717.925049
# ======>epoch:28,	 epoch_average_batch_loss:2593.247643============
#
# Epoch[29/100], Batch[1/600], batch_loss:2484.406250
# Epoch[29/100], Batch[101/600], batch_loss:2740.875732
# Epoch[29/100], Batch[201/600], batch_loss:2470.461914
# Epoch[29/100], Batch[301/600], batch_loss:2520.948486
# Epoch[29/100], Batch[401/600], batch_loss:2544.218262
# Epoch[29/100], Batch[501/600], batch_loss:2374.464844
# ======>epoch:29,	 epoch_average_batch_loss:2590.772385============
#
# Epoch[30/100], Batch[1/600], batch_loss:2566.028320
# Epoch[30/100], Batch[101/600], batch_loss:2647.332520
# Epoch[30/100], Batch[201/600], batch_loss:2697.427002
# Epoch[30/100], Batch[301/600], batch_loss:2489.060059
# Epoch[30/100], Batch[401/600], batch_loss:2572.050293
# Epoch[30/100], Batch[501/600], batch_loss:2561.320801
# ======>epoch:30,	 epoch_average_batch_loss:2586.290861============
#
# Epoch[31/100], Batch[1/600], batch_loss:2535.246582
# Epoch[31/100], Batch[101/600], batch_loss:2640.707764
# Epoch[31/100], Batch[201/600], batch_loss:2675.093262
# Epoch[31/100], Batch[301/600], batch_loss:2606.555664
# Epoch[31/100], Batch[401/600], batch_loss:2527.808350
# Epoch[31/100], Batch[501/600], batch_loss:2599.959961
# ======>epoch:31,	 epoch_average_batch_loss:2582.271432============
#
# save: ./img/cvae/epoch31.png
#
# Epoch[32/100], Batch[1/600], batch_loss:2703.925293
# Epoch[32/100], Batch[101/600], batch_loss:2573.404297
# Epoch[32/100], Batch[201/600], batch_loss:2569.742920
# Epoch[32/100], Batch[301/600], batch_loss:2642.673828
# Epoch[32/100], Batch[401/600], batch_loss:2646.686279
# Epoch[32/100], Batch[501/600], batch_loss:2604.815918
# ======>epoch:32,	 epoch_average_batch_loss:2579.754532============
#
# Epoch[33/100], Batch[1/600], batch_loss:2452.616699
# Epoch[33/100], Batch[101/600], batch_loss:2762.521973
# Epoch[33/100], Batch[201/600], batch_loss:2621.192383
# Epoch[33/100], Batch[301/600], batch_loss:2545.923340
# Epoch[33/100], Batch[401/600], batch_loss:2752.240723
# Epoch[33/100], Batch[501/600], batch_loss:2574.476074
# ======>epoch:33,	 epoch_average_batch_loss:2575.986729============
#
# Epoch[34/100], Batch[1/600], batch_loss:2531.453125
# Epoch[34/100], Batch[101/600], batch_loss:2489.153809
# Epoch[34/100], Batch[201/600], batch_loss:2505.519287
# Epoch[34/100], Batch[301/600], batch_loss:2516.571289
# Epoch[34/100], Batch[401/600], batch_loss:2658.841064
# Epoch[34/100], Batch[501/600], batch_loss:2723.946777
# ======>epoch:34,	 epoch_average_batch_loss:2573.704116============
#
# Epoch[35/100], Batch[1/600], batch_loss:2567.269531
# Epoch[35/100], Batch[101/600], batch_loss:2634.042725
# Epoch[35/100], Batch[201/600], batch_loss:2516.188477
# Epoch[35/100], Batch[301/600], batch_loss:2602.740723
# Epoch[35/100], Batch[401/600], batch_loss:2525.111816
# Epoch[35/100], Batch[501/600], batch_loss:2554.896729
# ======>epoch:35,	 epoch_average_batch_loss:2572.708472============
#
# Epoch[36/100], Batch[1/600], batch_loss:2612.390137
# Epoch[36/100], Batch[101/600], batch_loss:2742.274170
# Epoch[36/100], Batch[201/600], batch_loss:2533.508301
# Epoch[36/100], Batch[301/600], batch_loss:2588.123535
# Epoch[36/100], Batch[401/600], batch_loss:2598.083496
# Epoch[36/100], Batch[501/600], batch_loss:2618.776611
# ======>epoch:36,	 epoch_average_batch_loss:2570.728177============
#
# Epoch[37/100], Batch[1/600], batch_loss:2519.654785
# Epoch[37/100], Batch[101/600], batch_loss:2547.729004
# Epoch[37/100], Batch[201/600], batch_loss:2675.491943
# Epoch[37/100], Batch[301/600], batch_loss:2634.128906
# Epoch[37/100], Batch[401/600], batch_loss:2580.463379
# Epoch[37/100], Batch[501/600], batch_loss:2686.588623
# ======>epoch:37,	 epoch_average_batch_loss:2565.638610============
#
# Epoch[38/100], Batch[1/600], batch_loss:2535.302734
# Epoch[38/100], Batch[101/600], batch_loss:2533.405762
# Epoch[38/100], Batch[201/600], batch_loss:2569.790039
# Epoch[38/100], Batch[301/600], batch_loss:2472.370850
# Epoch[38/100], Batch[401/600], batch_loss:2555.684326
# Epoch[38/100], Batch[501/600], batch_loss:2455.782471
# ======>epoch:38,	 epoch_average_batch_loss:2565.969010============
#
# Epoch[39/100], Batch[1/600], batch_loss:2494.187988
# Epoch[39/100], Batch[101/600], batch_loss:2569.326904
# Epoch[39/100], Batch[201/600], batch_loss:2595.413574
# Epoch[39/100], Batch[301/600], batch_loss:2667.326660
# Epoch[39/100], Batch[401/600], batch_loss:2571.482422
# Epoch[39/100], Batch[501/600], batch_loss:2609.195068
# ======>epoch:39,	 epoch_average_batch_loss:2561.942150============
#
# Epoch[40/100], Batch[1/600], batch_loss:2584.539795
# Epoch[40/100], Batch[101/600], batch_loss:2621.111572
# Epoch[40/100], Batch[201/600], batch_loss:2568.902588
# Epoch[40/100], Batch[301/600], batch_loss:2657.256836
# Epoch[40/100], Batch[401/600], batch_loss:2530.513672
# Epoch[40/100], Batch[501/600], batch_loss:2675.391357
# ======>epoch:40,	 epoch_average_batch_loss:2557.439420============
#
# Epoch[41/100], Batch[1/600], batch_loss:2671.857422
# Epoch[41/100], Batch[101/600], batch_loss:2548.373535
# Epoch[41/100], Batch[201/600], batch_loss:2665.601807
# Epoch[41/100], Batch[301/600], batch_loss:2660.088867
# Epoch[41/100], Batch[401/600], batch_loss:2483.983643
# Epoch[41/100], Batch[501/600], batch_loss:2577.214600
# ======>epoch:41,	 epoch_average_batch_loss:2557.218847============
#
# save: ./img/cvae/epoch41.png
#
# Epoch[42/100], Batch[1/600], batch_loss:2522.185303
# Epoch[42/100], Batch[101/600], batch_loss:2482.802246
# Epoch[42/100], Batch[201/600], batch_loss:2579.316650
# Epoch[42/100], Batch[301/600], batch_loss:2435.335449
# Epoch[42/100], Batch[401/600], batch_loss:2606.084717
# Epoch[42/100], Batch[501/600], batch_loss:2757.074707
# ======>epoch:42,	 epoch_average_batch_loss:2553.560396============
#
# Epoch[43/100], Batch[1/600], batch_loss:2442.382568
# Epoch[43/100], Batch[101/600], batch_loss:2615.821777
# Epoch[43/100], Batch[201/600], batch_loss:2563.870361
# Epoch[43/100], Batch[301/600], batch_loss:2501.195557
# Epoch[43/100], Batch[401/600], batch_loss:2536.343262
# Epoch[43/100], Batch[501/600], batch_loss:2500.813965
# ======>epoch:43,	 epoch_average_batch_loss:2551.032159============
#
# Epoch[44/100], Batch[1/600], batch_loss:2672.613281
# Epoch[44/100], Batch[101/600], batch_loss:2439.719238
# Epoch[44/100], Batch[201/600], batch_loss:2531.642578
# Epoch[44/100], Batch[301/600], batch_loss:2639.907227
# Epoch[44/100], Batch[401/600], batch_loss:2579.804199
# Epoch[44/100], Batch[501/600], batch_loss:2403.091309
# ======>epoch:44,	 epoch_average_batch_loss:2550.761208============
#
# Epoch[45/100], Batch[1/600], batch_loss:2521.277344
# Epoch[45/100], Batch[101/600], batch_loss:2545.067627
# Epoch[45/100], Batch[201/600], batch_loss:2738.047852
# Epoch[45/100], Batch[301/600], batch_loss:2563.473633
# Epoch[45/100], Batch[401/600], batch_loss:2704.553711
# Epoch[45/100], Batch[501/600], batch_loss:2636.466064
# ======>epoch:45,	 epoch_average_batch_loss:2548.271463============
#
# Epoch[46/100], Batch[1/600], batch_loss:2616.341797
# Epoch[46/100], Batch[101/600], batch_loss:2579.817139
# Epoch[46/100], Batch[201/600], batch_loss:2552.062012
# Epoch[46/100], Batch[301/600], batch_loss:2531.412109
# Epoch[46/100], Batch[401/600], batch_loss:2572.041748
# Epoch[46/100], Batch[501/600], batch_loss:2460.646973
# ======>epoch:46,	 epoch_average_batch_loss:2547.431443============
#
# Epoch[47/100], Batch[1/600], batch_loss:2457.508545
# Epoch[47/100], Batch[101/600], batch_loss:2433.729004
# Epoch[47/100], Batch[201/600], batch_loss:2337.616699
# Epoch[47/100], Batch[301/600], batch_loss:2599.186768
# Epoch[47/100], Batch[401/600], batch_loss:2707.641357
# Epoch[47/100], Batch[501/600], batch_loss:2609.571533
# ======>epoch:47,	 epoch_average_batch_loss:2545.155438============
#
# Epoch[48/100], Batch[1/600], batch_loss:2327.302979
# Epoch[48/100], Batch[101/600], batch_loss:2405.076660
# Epoch[48/100], Batch[201/600], batch_loss:2496.708984
# Epoch[48/100], Batch[301/600], batch_loss:2377.425781
# Epoch[48/100], Batch[401/600], batch_loss:2408.159912
# Epoch[48/100], Batch[501/600], batch_loss:2436.399414
# ======>epoch:48,	 epoch_average_batch_loss:2544.079218============
#
# Epoch[49/100], Batch[1/600], batch_loss:2548.386230
# Epoch[49/100], Batch[101/600], batch_loss:2407.821777
# Epoch[49/100], Batch[201/600], batch_loss:2555.473389
# Epoch[49/100], Batch[301/600], batch_loss:2578.918701
# Epoch[49/100], Batch[401/600], batch_loss:2619.624268
# Epoch[49/100], Batch[501/600], batch_loss:2536.719727
# ======>epoch:49,	 epoch_average_batch_loss:2541.523492============
#
# Epoch[50/100], Batch[1/600], batch_loss:2541.864746
# Epoch[50/100], Batch[101/600], batch_loss:2643.822266
# Epoch[50/100], Batch[201/600], batch_loss:2479.556396
# Epoch[50/100], Batch[301/600], batch_loss:2546.690918
# Epoch[50/100], Batch[401/600], batch_loss:2400.837891
# Epoch[50/100], Batch[501/600], batch_loss:2659.774658
# ======>epoch:50,	 epoch_average_batch_loss:2539.982869============
#
# Epoch[51/100], Batch[1/600], batch_loss:2471.294678
# Epoch[51/100], Batch[101/600], batch_loss:2622.778076
# Epoch[51/100], Batch[201/600], batch_loss:2504.875000
# Epoch[51/100], Batch[301/600], batch_loss:2637.750977
# Epoch[51/100], Batch[401/600], batch_loss:2462.712891
# Epoch[51/100], Batch[501/600], batch_loss:2617.136719
# ======>epoch:51,	 epoch_average_batch_loss:2538.939632============
#
# save: ./img/cvae/epoch51.png
#
# Epoch[52/100], Batch[1/600], batch_loss:2472.992432
# Epoch[52/100], Batch[101/600], batch_loss:2513.742432
# Epoch[52/100], Batch[201/600], batch_loss:2483.230957
# Epoch[52/100], Batch[301/600], batch_loss:2571.547363
# Epoch[52/100], Batch[401/600], batch_loss:2412.697266
# Epoch[52/100], Batch[501/600], batch_loss:2564.343506
# ======>epoch:52,	 epoch_average_batch_loss:2534.729867============
#
# Epoch[53/100], Batch[1/600], batch_loss:2458.314453
# Epoch[53/100], Batch[101/600], batch_loss:2617.670410
# Epoch[53/100], Batch[201/600], batch_loss:2460.178955
# Epoch[53/100], Batch[301/600], batch_loss:2578.583008
# Epoch[53/100], Batch[401/600], batch_loss:2517.820801
# Epoch[53/100], Batch[501/600], batch_loss:2390.965820
# ======>epoch:53,	 epoch_average_batch_loss:2532.565689============
#
# Epoch[54/100], Batch[1/600], batch_loss:2594.956055
# Epoch[54/100], Batch[101/600], batch_loss:2578.222168
# Epoch[54/100], Batch[201/600], batch_loss:2616.237793
# Epoch[54/100], Batch[301/600], batch_loss:2650.261963
# Epoch[54/100], Batch[401/600], batch_loss:2555.071289
# Epoch[54/100], Batch[501/600], batch_loss:2630.047852
# ======>epoch:54,	 epoch_average_batch_loss:2534.878538============
#
# Epoch[55/100], Batch[1/600], batch_loss:2544.183350
# Epoch[55/100], Batch[101/600], batch_loss:2560.134521
# Epoch[55/100], Batch[201/600], batch_loss:2650.105469
# Epoch[55/100], Batch[301/600], batch_loss:2584.760986
# Epoch[55/100], Batch[401/600], batch_loss:2596.393799
# Epoch[55/100], Batch[501/600], batch_loss:2289.519043
# ======>epoch:55,	 epoch_average_batch_loss:2534.132328============
#
# Epoch[56/100], Batch[1/600], batch_loss:2675.001465
# Epoch[56/100], Batch[101/600], batch_loss:2345.031738
# Epoch[56/100], Batch[201/600], batch_loss:2559.979004
# Epoch[56/100], Batch[301/600], batch_loss:2491.703613
# Epoch[56/100], Batch[401/600], batch_loss:2709.572510
# Epoch[56/100], Batch[501/600], batch_loss:2537.411133
# ======>epoch:56,	 epoch_average_batch_loss:2529.635039============
#
# Epoch[57/100], Batch[1/600], batch_loss:2514.133301
# Epoch[57/100], Batch[101/600], batch_loss:2404.817871
# Epoch[57/100], Batch[201/600], batch_loss:2482.817139
# Epoch[57/100], Batch[301/600], batch_loss:2578.435791
# Epoch[57/100], Batch[401/600], batch_loss:2515.245117
# Epoch[57/100], Batch[501/600], batch_loss:2542.801758
# ======>epoch:57,	 epoch_average_batch_loss:2528.583388============
#
# Epoch[58/100], Batch[1/600], batch_loss:2598.518555
# Epoch[58/100], Batch[101/600], batch_loss:2327.547119
# Epoch[58/100], Batch[201/600], batch_loss:2497.211182
# Epoch[58/100], Batch[301/600], batch_loss:2471.828613
# Epoch[58/100], Batch[401/600], batch_loss:2470.098145
# Epoch[58/100], Batch[501/600], batch_loss:2511.657471
# ======>epoch:58,	 epoch_average_batch_loss:2526.045876============
#
# Epoch[59/100], Batch[1/600], batch_loss:2506.787598
# Epoch[59/100], Batch[101/600], batch_loss:2439.551270
# Epoch[59/100], Batch[201/600], batch_loss:2567.425781
# Epoch[59/100], Batch[301/600], batch_loss:2429.648438
# Epoch[59/100], Batch[401/600], batch_loss:2509.420410
# Epoch[59/100], Batch[501/600], batch_loss:2386.244629
# ======>epoch:59,	 epoch_average_batch_loss:2524.957677============
#
# Epoch[60/100], Batch[1/600], batch_loss:2600.007812
# Epoch[60/100], Batch[101/600], batch_loss:2625.810303
# Epoch[60/100], Batch[201/600], batch_loss:2499.524658
# Epoch[60/100], Batch[301/600], batch_loss:2681.194580
# Epoch[60/100], Batch[401/600], batch_loss:2424.501465
# Epoch[60/100], Batch[501/600], batch_loss:2482.474121
# ======>epoch:60,	 epoch_average_batch_loss:2527.357297============
#
# Epoch[61/100], Batch[1/600], batch_loss:2456.395264
# Epoch[61/100], Batch[101/600], batch_loss:2602.986816
# Epoch[61/100], Batch[201/600], batch_loss:2500.125488
# Epoch[61/100], Batch[301/600], batch_loss:2539.780273
# Epoch[61/100], Batch[401/600], batch_loss:2560.307373
# Epoch[61/100], Batch[501/600], batch_loss:2585.791504
# ======>epoch:61,	 epoch_average_batch_loss:2523.567544============
#
# save: ./img/cvae/epoch61.png
#
# Epoch[62/100], Batch[1/600], batch_loss:2617.027344
# Epoch[62/100], Batch[101/600], batch_loss:2527.669434
# Epoch[62/100], Batch[201/600], batch_loss:2589.046387
# Epoch[62/100], Batch[301/600], batch_loss:2496.518066
# Epoch[62/100], Batch[401/600], batch_loss:2450.288086
# Epoch[62/100], Batch[501/600], batch_loss:2738.138184
# ======>epoch:62,	 epoch_average_batch_loss:2521.255521============
#
# Epoch[63/100], Batch[1/600], batch_loss:2468.760742
# Epoch[63/100], Batch[101/600], batch_loss:2457.435059
# Epoch[63/100], Batch[201/600], batch_loss:2578.684082
# Epoch[63/100], Batch[301/600], batch_loss:2489.904053
# Epoch[63/100], Batch[401/600], batch_loss:2697.415527
# Epoch[63/100], Batch[501/600], batch_loss:2470.109619
# ======>epoch:63,	 epoch_average_batch_loss:2519.011069============
#
# Epoch[64/100], Batch[1/600], batch_loss:2535.322510
# Epoch[64/100], Batch[101/600], batch_loss:2613.527588
# Epoch[64/100], Batch[201/600], batch_loss:2496.072754
# Epoch[64/100], Batch[301/600], batch_loss:2538.250000
# Epoch[64/100], Batch[401/600], batch_loss:2596.851074
# Epoch[64/100], Batch[501/600], batch_loss:2560.750732
# ======>epoch:64,	 epoch_average_batch_loss:2517.584848============
#
# Epoch[65/100], Batch[1/600], batch_loss:2386.673828
# Epoch[65/100], Batch[101/600], batch_loss:2466.682861
# Epoch[65/100], Batch[201/600], batch_loss:2463.341797
# Epoch[65/100], Batch[301/600], batch_loss:2492.729980
# Epoch[65/100], Batch[401/600], batch_loss:2520.531250
# Epoch[65/100], Batch[501/600], batch_loss:2561.916504
# ======>epoch:65,	 epoch_average_batch_loss:2519.176635============
#
# Epoch[66/100], Batch[1/600], batch_loss:2620.237793
# Epoch[66/100], Batch[101/600], batch_loss:2401.107910
# Epoch[66/100], Batch[201/600], batch_loss:2319.446045
# Epoch[66/100], Batch[301/600], batch_loss:2462.024170
# Epoch[66/100], Batch[401/600], batch_loss:2492.577881
# Epoch[66/100], Batch[501/600], batch_loss:2566.993652
# ======>epoch:66,	 epoch_average_batch_loss:2516.914483============
#
# Epoch[67/100], Batch[1/600], batch_loss:2525.105469
# Epoch[67/100], Batch[101/600], batch_loss:2427.126465
# Epoch[67/100], Batch[201/600], batch_loss:2515.874023
# Epoch[67/100], Batch[301/600], batch_loss:2416.857422
# Epoch[67/100], Batch[401/600], batch_loss:2439.355469
# Epoch[67/100], Batch[501/600], batch_loss:2552.949219
# ======>epoch:67,	 epoch_average_batch_loss:2515.586794============
#
# Epoch[68/100], Batch[1/600], batch_loss:2484.783203
# Epoch[68/100], Batch[101/600], batch_loss:2467.774414
# Epoch[68/100], Batch[201/600], batch_loss:2610.271973
# Epoch[68/100], Batch[301/600], batch_loss:2599.601074
# Epoch[68/100], Batch[401/600], batch_loss:2399.996582
# Epoch[68/100], Batch[501/600], batch_loss:2498.173828
# ======>epoch:68,	 epoch_average_batch_loss:2516.359174============
#
# Epoch[69/100], Batch[1/600], batch_loss:2506.720703
# Epoch[69/100], Batch[101/600], batch_loss:2410.923096
# Epoch[69/100], Batch[201/600], batch_loss:2524.155273
# Epoch[69/100], Batch[301/600], batch_loss:2530.013428
# Epoch[69/100], Batch[401/600], batch_loss:2389.755615
# Epoch[69/100], Batch[501/600], batch_loss:2412.370605
# ======>epoch:69,	 epoch_average_batch_loss:2511.559150============
#
# Epoch[70/100], Batch[1/600], batch_loss:2721.175293
# Epoch[70/100], Batch[101/600], batch_loss:2420.720703
# Epoch[70/100], Batch[201/600], batch_loss:2575.171631
# Epoch[70/100], Batch[301/600], batch_loss:2450.592773
# Epoch[70/100], Batch[401/600], batch_loss:2301.870605
# Epoch[70/100], Batch[501/600], batch_loss:2523.368652
# ======>epoch:70,	 epoch_average_batch_loss:2512.501766============
#
# Epoch[71/100], Batch[1/600], batch_loss:2473.439453
# Epoch[71/100], Batch[101/600], batch_loss:2491.278320
# Epoch[71/100], Batch[201/600], batch_loss:2573.044678
# Epoch[71/100], Batch[301/600], batch_loss:2655.520752
# Epoch[71/100], Batch[401/600], batch_loss:2488.279541
# Epoch[71/100], Batch[501/600], batch_loss:2416.835693
# ======>epoch:71,	 epoch_average_batch_loss:2509.779541============
#
# save: ./img/cvae/epoch71.png
#
# Epoch[72/100], Batch[1/600], batch_loss:2574.481445
# Epoch[72/100], Batch[101/600], batch_loss:2424.154053
# Epoch[72/100], Batch[201/600], batch_loss:2335.026367
# Epoch[72/100], Batch[301/600], batch_loss:2538.511230
# Epoch[72/100], Batch[401/600], batch_loss:2565.364990
# Epoch[72/100], Batch[501/600], batch_loss:2515.097656
# ======>epoch:72,	 epoch_average_batch_loss:2508.745487============
#
# Epoch[73/100], Batch[1/600], batch_loss:2450.987549
# Epoch[73/100], Batch[101/600], batch_loss:2518.164062
# Epoch[73/100], Batch[201/600], batch_loss:2440.566650
# Epoch[73/100], Batch[301/600], batch_loss:2405.824219
# Epoch[73/100], Batch[401/600], batch_loss:2581.428711
# Epoch[73/100], Batch[501/600], batch_loss:2462.461670
# ======>epoch:73,	 epoch_average_batch_loss:2509.018203============
#
# Epoch[74/100], Batch[1/600], batch_loss:2414.181152
# Epoch[74/100], Batch[101/600], batch_loss:2445.704346
# Epoch[74/100], Batch[201/600], batch_loss:2389.000977
# Epoch[74/100], Batch[301/600], batch_loss:2363.850586
# Epoch[74/100], Batch[401/600], batch_loss:2588.864258
# Epoch[74/100], Batch[501/600], batch_loss:2492.134521
# ======>epoch:74,	 epoch_average_batch_loss:2507.052598============
#
# Epoch[75/100], Batch[1/600], batch_loss:2616.294434
# Epoch[75/100], Batch[101/600], batch_loss:2591.067139
# Epoch[75/100], Batch[201/600], batch_loss:2371.233887
# Epoch[75/100], Batch[301/600], batch_loss:2547.542480
# Epoch[75/100], Batch[401/600], batch_loss:2484.678711
# Epoch[75/100], Batch[501/600], batch_loss:2435.764404
# ======>epoch:75,	 epoch_average_batch_loss:2508.900282============
#
# Epoch[76/100], Batch[1/600], batch_loss:2401.401367
# Epoch[76/100], Batch[101/600], batch_loss:2403.440918
# Epoch[76/100], Batch[201/600], batch_loss:2410.768066
# Epoch[76/100], Batch[301/600], batch_loss:2560.860107
# Epoch[76/100], Batch[401/600], batch_loss:2494.128418
# Epoch[76/100], Batch[501/600], batch_loss:2432.570557
# ======>epoch:76,	 epoch_average_batch_loss:2505.129869============
#
# Epoch[77/100], Batch[1/600], batch_loss:2389.609863
# Epoch[77/100], Batch[101/600], batch_loss:2386.149170
# Epoch[77/100], Batch[201/600], batch_loss:2441.618164
# Epoch[77/100], Batch[301/600], batch_loss:2714.933105
# Epoch[77/100], Batch[401/600], batch_loss:2517.953125
# Epoch[77/100], Batch[501/600], batch_loss:2351.673584
# ======>epoch:77,	 epoch_average_batch_loss:2504.526141============
#
# Epoch[78/100], Batch[1/600], batch_loss:2438.281738
# Epoch[78/100], Batch[101/600], batch_loss:2497.176025
# Epoch[78/100], Batch[201/600], batch_loss:2561.716309
# Epoch[78/100], Batch[301/600], batch_loss:2455.562256
# Epoch[78/100], Batch[401/600], batch_loss:2640.225830
# Epoch[78/100], Batch[501/600], batch_loss:2464.373535
# ======>epoch:78,	 epoch_average_batch_loss:2504.631924============
#
# Epoch[79/100], Batch[1/600], batch_loss:2520.720215
# Epoch[79/100], Batch[101/600], batch_loss:2443.520020
# Epoch[79/100], Batch[201/600], batch_loss:2473.451416
# Epoch[79/100], Batch[301/600], batch_loss:2467.906738
# Epoch[79/100], Batch[401/600], batch_loss:2341.183105
# Epoch[79/100], Batch[501/600], batch_loss:2546.916992
# ======>epoch:79,	 epoch_average_batch_loss:2503.898442============
#
# Epoch[80/100], Batch[1/600], batch_loss:2332.195312
# Epoch[80/100], Batch[101/600], batch_loss:2463.396729
# Epoch[80/100], Batch[201/600], batch_loss:2559.496094
# Epoch[80/100], Batch[301/600], batch_loss:2674.183838
# Epoch[80/100], Batch[401/600], batch_loss:2483.951660
# Epoch[80/100], Batch[501/600], batch_loss:2625.206299
# ======>epoch:80,	 epoch_average_batch_loss:2504.322748============
#
# Epoch[81/100], Batch[1/600], batch_loss:2474.331055
# Epoch[81/100], Batch[101/600], batch_loss:2461.145264
# Epoch[81/100], Batch[201/600], batch_loss:2464.418701
# Epoch[81/100], Batch[301/600], batch_loss:2368.430176
# Epoch[81/100], Batch[401/600], batch_loss:2448.289551
# Epoch[81/100], Batch[501/600], batch_loss:2517.349609
# ======>epoch:81,	 epoch_average_batch_loss:2502.143678============
#
# save: ./img/cvae/epoch81.png
#
# Epoch[82/100], Batch[1/600], batch_loss:2580.316650
# Epoch[82/100], Batch[101/600], batch_loss:2676.186523
# Epoch[82/100], Batch[201/600], batch_loss:2690.359863
# Epoch[82/100], Batch[301/600], batch_loss:2593.396484
# Epoch[82/100], Batch[401/600], batch_loss:2504.047852
# Epoch[82/100], Batch[501/600], batch_loss:2387.124268
# ======>epoch:82,	 epoch_average_batch_loss:2501.065549============
#
# Epoch[83/100], Batch[1/600], batch_loss:2525.064453
# Epoch[83/100], Batch[101/600], batch_loss:2530.211182
# Epoch[83/100], Batch[201/600], batch_loss:2565.521484
# Epoch[83/100], Batch[301/600], batch_loss:2438.827881
# Epoch[83/100], Batch[401/600], batch_loss:2559.027100
# Epoch[83/100], Batch[501/600], batch_loss:2485.674316
# ======>epoch:83,	 epoch_average_batch_loss:2501.139250============
#
# Epoch[84/100], Batch[1/600], batch_loss:2498.349854
# Epoch[84/100], Batch[101/600], batch_loss:2423.588623
# Epoch[84/100], Batch[201/600], batch_loss:2438.867920
# Epoch[84/100], Batch[301/600], batch_loss:2435.310059
# Epoch[84/100], Batch[401/600], batch_loss:2461.533203
# Epoch[84/100], Batch[501/600], batch_loss:2430.120117
# ======>epoch:84,	 epoch_average_batch_loss:2500.172034============
#
# Epoch[85/100], Batch[1/600], batch_loss:2395.908691
# Epoch[85/100], Batch[101/600], batch_loss:2274.824707
# Epoch[85/100], Batch[201/600], batch_loss:2410.870361
# Epoch[85/100], Batch[301/600], batch_loss:2803.415039
# Epoch[85/100], Batch[401/600], batch_loss:2582.860840
# Epoch[85/100], Batch[501/600], batch_loss:2550.479248
# ======>epoch:85,	 epoch_average_batch_loss:2498.279660============
#
# Epoch[86/100], Batch[1/600], batch_loss:2536.130371
# Epoch[86/100], Batch[101/600], batch_loss:2484.895020
# Epoch[86/100], Batch[201/600], batch_loss:2506.811035
# Epoch[86/100], Batch[301/600], batch_loss:2463.960938
# Epoch[86/100], Batch[401/600], batch_loss:2483.793213
# Epoch[86/100], Batch[501/600], batch_loss:2510.861816
# ======>epoch:86,	 epoch_average_batch_loss:2497.818180============
#
# Epoch[87/100], Batch[1/600], batch_loss:2664.575439
# Epoch[87/100], Batch[101/600], batch_loss:2545.797363
# Epoch[87/100], Batch[201/600], batch_loss:2400.827881
# Epoch[87/100], Batch[301/600], batch_loss:2455.824951
# Epoch[87/100], Batch[401/600], batch_loss:2497.864502
# Epoch[87/100], Batch[501/600], batch_loss:2337.034668
# ======>epoch:87,	 epoch_average_batch_loss:2498.644504============
#
# Epoch[88/100], Batch[1/600], batch_loss:2519.894287
# Epoch[88/100], Batch[101/600], batch_loss:2469.070312
# Epoch[88/100], Batch[201/600], batch_loss:2434.020020
# Epoch[88/100], Batch[301/600], batch_loss:2535.017334
# Epoch[88/100], Batch[401/600], batch_loss:2566.899414
# Epoch[88/100], Batch[501/600], batch_loss:2420.384033
# ======>epoch:88,	 epoch_average_batch_loss:2497.296542============
#
# Epoch[89/100], Batch[1/600], batch_loss:2359.545166
# Epoch[89/100], Batch[101/600], batch_loss:2550.463135
# Epoch[89/100], Batch[201/600], batch_loss:2384.777588
# Epoch[89/100], Batch[301/600], batch_loss:2480.448975
# Epoch[89/100], Batch[401/600], batch_loss:2359.420898
# Epoch[89/100], Batch[501/600], batch_loss:2575.759277
# ======>epoch:89,	 epoch_average_batch_loss:2495.385811============
#
# Epoch[90/100], Batch[1/600], batch_loss:2450.544678
# Epoch[90/100], Batch[101/600], batch_loss:2509.653809
# Epoch[90/100], Batch[201/600], batch_loss:2458.250488
# Epoch[90/100], Batch[301/600], batch_loss:2491.141846
# Epoch[90/100], Batch[401/600], batch_loss:2401.768311
# Epoch[90/100], Batch[501/600], batch_loss:2477.999023
# ======>epoch:90,	 epoch_average_batch_loss:2493.908613============
#
# Epoch[91/100], Batch[1/600], batch_loss:2464.311035
# Epoch[91/100], Batch[101/600], batch_loss:2503.458496
# Epoch[91/100], Batch[201/600], batch_loss:2500.402832
# Epoch[91/100], Batch[301/600], batch_loss:2562.507324
# Epoch[91/100], Batch[401/600], batch_loss:2344.368164
# Epoch[91/100], Batch[501/600], batch_loss:2321.412598
# ======>epoch:91,	 epoch_average_batch_loss:2494.971370============
#
# save: ./img/cvae/epoch91.png
#
# Epoch[92/100], Batch[1/600], batch_loss:2544.016602
# Epoch[92/100], Batch[101/600], batch_loss:2388.949219
# Epoch[92/100], Batch[201/600], batch_loss:2400.958008
# Epoch[92/100], Batch[301/600], batch_loss:2459.878906
# Epoch[92/100], Batch[401/600], batch_loss:2390.055908
# Epoch[92/100], Batch[501/600], batch_loss:2299.795166
# ======>epoch:92,	 epoch_average_batch_loss:2492.582845============
#
# Epoch[93/100], Batch[1/600], batch_loss:2614.500244
# Epoch[93/100], Batch[101/600], batch_loss:2428.111572
# Epoch[93/100], Batch[201/600], batch_loss:2486.386230
# Epoch[93/100], Batch[301/600], batch_loss:2546.400879
# Epoch[93/100], Batch[401/600], batch_loss:2335.199707
# Epoch[93/100], Batch[501/600], batch_loss:2534.394043
# ======>epoch:93,	 epoch_average_batch_loss:2491.404113============
#
# Epoch[94/100], Batch[1/600], batch_loss:2454.891357
# Epoch[94/100], Batch[101/600], batch_loss:2439.497803
# Epoch[94/100], Batch[201/600], batch_loss:2604.550049
# Epoch[94/100], Batch[301/600], batch_loss:2566.642822
# Epoch[94/100], Batch[401/600], batch_loss:2651.246094
# Epoch[94/100], Batch[501/600], batch_loss:2470.169922
# ======>epoch:94,	 epoch_average_batch_loss:2493.431630============
#
# Epoch[95/100], Batch[1/600], batch_loss:2378.749268
# Epoch[95/100], Batch[101/600], batch_loss:2610.391602
# Epoch[95/100], Batch[201/600], batch_loss:2540.036865
# Epoch[95/100], Batch[301/600], batch_loss:2602.166992
# Epoch[95/100], Batch[401/600], batch_loss:2485.571289
# Epoch[95/100], Batch[501/600], batch_loss:2396.184326
# ======>epoch:95,	 epoch_average_batch_loss:2491.138689============
#
# Epoch[96/100], Batch[1/600], batch_loss:2352.237793
# Epoch[96/100], Batch[101/600], batch_loss:2440.633057
# Epoch[96/100], Batch[201/600], batch_loss:2534.408203
# Epoch[96/100], Batch[301/600], batch_loss:2694.732178
# Epoch[96/100], Batch[401/600], batch_loss:2558.726074
# Epoch[96/100], Batch[501/600], batch_loss:2537.473145
# ======>epoch:96,	 epoch_average_batch_loss:2489.573499============
#
# Epoch[97/100], Batch[1/600], batch_loss:2550.944336
# Epoch[97/100], Batch[101/600], batch_loss:2507.525635
# Epoch[97/100], Batch[201/600], batch_loss:2510.275879
# Epoch[97/100], Batch[301/600], batch_loss:2361.640137
# Epoch[97/100], Batch[401/600], batch_loss:2471.131104
# Epoch[97/100], Batch[501/600], batch_loss:2439.673340
# ======>epoch:97,	 epoch_average_batch_loss:2490.923048============
#
# Epoch[98/100], Batch[1/600], batch_loss:2478.971680
# Epoch[98/100], Batch[101/600], batch_loss:2398.139160
# Epoch[98/100], Batch[201/600], batch_loss:2497.617188
# Epoch[98/100], Batch[301/600], batch_loss:2507.182129
# Epoch[98/100], Batch[401/600], batch_loss:2389.284180
# Epoch[98/100], Batch[501/600], batch_loss:2688.148926
# ======>epoch:98,	 epoch_average_batch_loss:2489.122847============
#
# Epoch[99/100], Batch[1/600], batch_loss:2678.493652
# Epoch[99/100], Batch[101/600], batch_loss:2528.259766
# Epoch[99/100], Batch[201/600], batch_loss:2507.469238
# Epoch[99/100], Batch[301/600], batch_loss:2580.844727
# Epoch[99/100], Batch[401/600], batch_loss:2472.560791
# Epoch[99/100], Batch[501/600], batch_loss:2377.091797
# ======>epoch:99,	 epoch_average_batch_loss:2489.524165============
#
# Epoch[100/100], Batch[1/600], batch_loss:2561.295898
# Epoch[100/100], Batch[101/600], batch_loss:2601.420898
# Epoch[100/100], Batch[201/600], batch_loss:2367.347656
# Epoch[100/100], Batch[301/600], batch_loss:2540.477295
# Epoch[100/100], Batch[401/600], batch_loss:2412.673828
# Epoch[100/100], Batch[501/600], batch_loss:2431.562012
# ======>epoch:100,	 epoch_average_batch_loss:2487.085080============
#
# save raw image:./img/cvae/raw/png
#
# save model..........

# %%
import torch

tensorz = torch.randn(4)  # 假设tensorz是大小为[4]的张量

print(tensorz)
tensor = tensorz.view(1, 4)  # 使用view函数将张量大小转换为[1, 4]
print(tensor)
print(tensor.size())  # 打印转换后张量的大小
# Out:
# tensor([ 0.6743,  0.1043, -0.8124,  0.4877])
# tensor([[ 0.6743,  0.1043, -0.8124,  0.4877]])
# torch.Size([1, 4])
