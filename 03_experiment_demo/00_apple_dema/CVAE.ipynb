# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
from torch.utils.data import DataLoader
import utils


class CVAE(nn.Module):
    """Implementation of CVAE(Conditional Variational Auto-Encoder)"""
    def __init__(self, feature_size, class_size, latent_size):
        super(CVAE, self).__init__()

        self.fc1 = nn.Linear(feature_size + class_size, 200)
        self.fc2_mu = nn.Linear(200, latent_size)
        self.fc2_log_std = nn.Linear(200, latent_size)
        self.fc3 = nn.Linear(latent_size + class_size, 200)
        self.fc4 = nn.Linear(200, feature_size)

    def encode(self, x, y):
        h1 = F.relu(self.fc1(torch.cat([x, y], dim=1)))  # concat features and labels
        mu = self.fc2_mu(h1)
        log_std = self.fc2_log_std(h1)
        return mu, log_std

    def decode(self, z, y):
        h3 = F.relu(self.fc3(torch.cat([z, y], dim=1)))  # concat latents and labels
        recon = torch.sigmoid(self.fc4(h3))  # use sigmoid because the input image's pixel is between 0-1
        return recon

    def reparametrize(self, mu, log_std):
        std = torch.exp(log_std)
        eps = torch.randn_like(std)  # simple from standard normal distribution
        z = mu + eps * std
        return z

    def forward(self, x, y):
        mu, log_std = self.encode(x, y)
        z = self.reparametrize(mu, log_std)
        recon = self.decode(z, y)
        return recon, mu, log_std

    def loss_function(self, recon, x, mu, log_std) -> torch.Tensor:
        recon_loss = F.mse_loss(recon, x, reduction="sum")  # use "mean" may have a bad effect on gradients
        kl_loss = -0.5 * (1 + 2*log_std - mu.pow(2) - torch.exp(2*log_std))
        kl_loss = torch.sum(kl_loss)
        loss = recon_loss + kl_loss
        return loss


if __name__ == '__main__':
    epochs = 100
    batch_size = 100

    recon = None
    img = None

    utils.make_dir("./img/cvae")
    utils.make_dir("./model_weights/cvae")

    train_data = torchvision.datasets.MNIST(
        root='./mnist',
        train=True,
        transform=torchvision.transforms.ToTensor(),
        download=True
    )

    data_loader = DataLoader(train_data, batch_size=100, shuffle=True)

    cvae = CVAE(feature_size=784, class_size=10, latent_size=10)

    optimizer = torch.optim.Adam(cvae.parameters(), lr=1e-3)

    for epoch in range(100):
        train_loss = 0
        i = 0
        for batch_id, data in enumerate(data_loader):
            img, label = data
            inputs = img.reshape(img.shape[0], -1)
            y = utils.to_one_hot(label.reshape(-1, 1), num_class=10)
            recon, mu, log_std = cvae(inputs, y)
            loss = cvae.loss_function(recon, inputs, mu, log_std)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            i += 1

            if batch_id % 100 == 0:
                print("Epoch[{}/{}], Batch[{}/{}], batch_loss:{:.6f}".format(
                    epoch+1, epochs, batch_id+1, len(data_loader), loss.item()))

        print("======>epoch:{},\t epoch_average_batch_loss:{:.6f}============".format(epoch+1, train_loss/i), "\n")

        # save imgs
        if epoch % 10 == 0:
            imgs = utils.to_img(recon.detach())
            path = "./img/cvae/epoch{}.png".format(epoch+1)
            torchvision.utils.save_image(imgs, path, nrow=10)
            print("save:", path, "\n")

    torchvision.utils.save_image(img, "./img/cvae/raw.png", nrow=10)
    print("save raw image:./img/cvae/raw/png", "\n")

    # save val model
    utils.save_model(cvae, "./model_weights/cvae/cvae_weights.pth")
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./mnist\MNIST\raw\train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 502: Bad Gateway
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist\MNIST\raw\train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./mnist\MNIST\raw\train-images-idx3-ubyte.gz to ./mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 502: Bad Gateway
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist\MNIST\raw\train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./mnist\MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 502: Bad Gateway
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist\MNIST\raw\t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./mnist\MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./mnist\MNIST\raw\t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./mnist\MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist\MNIST\raw
#
# Epoch[1/100], Batch[1/600], batch_loss:18272.736328
# Epoch[1/100], Batch[101/600], batch_loss:5005.036133
# Epoch[1/100], Batch[201/600], batch_loss:4113.258301
# Epoch[1/100], Batch[301/600], batch_loss:4041.352295
# Epoch[1/100], Batch[401/600], batch_loss:3900.162354
# Epoch[1/100], Batch[501/600], batch_loss:3630.965332
# ======>epoch:1,	 epoch_average_batch_loss:4515.321669============
#
# save: ./img/cvae/epoch1.png
#
# Epoch[2/100], Batch[1/600], batch_loss:3556.889893
# Epoch[2/100], Batch[101/600], batch_loss:3431.774414
# Epoch[2/100], Batch[201/600], batch_loss:3319.929688
# Epoch[2/100], Batch[301/600], batch_loss:3222.106445
# Epoch[2/100], Batch[401/600], batch_loss:3219.902832
# Epoch[2/100], Batch[501/600], batch_loss:3205.185059
# ======>epoch:2,	 epoch_average_batch_loss:3284.607135============
#
# Epoch[3/100], Batch[1/600], batch_loss:3195.088135
# Epoch[3/100], Batch[101/600], batch_loss:3089.370117
# Epoch[3/100], Batch[201/600], batch_loss:3127.342773
# Epoch[3/100], Batch[301/600], batch_loss:2959.485596
# Epoch[3/100], Batch[401/600], batch_loss:3100.478027
# Epoch[3/100], Batch[501/600], batch_loss:2912.529541
# ======>epoch:3,	 epoch_average_batch_loss:3073.753341============
#
# Epoch[4/100], Batch[1/600], batch_loss:3000.151367
# Epoch[4/100], Batch[101/600], batch_loss:3117.149170
# Epoch[4/100], Batch[201/600], batch_loss:3060.087158
# Epoch[4/100], Batch[301/600], batch_loss:3073.346436
# Epoch[4/100], Batch[401/600], batch_loss:3187.239258
# Epoch[4/100], Batch[501/600], batch_loss:2925.519043
# ======>epoch:4,	 epoch_average_batch_loss:2961.751805============
#
# Epoch[5/100], Batch[1/600], batch_loss:2890.404053
# Epoch[5/100], Batch[101/600], batch_loss:2912.830078
# Epoch[5/100], Batch[201/600], batch_loss:3205.453125
# Epoch[5/100], Batch[301/600], batch_loss:2931.276611
# Epoch[5/100], Batch[401/600], batch_loss:2853.697754
# Epoch[5/100], Batch[501/600], batch_loss:3044.607910
# ======>epoch:5,	 epoch_average_batch_loss:2886.867529============
#
# Epoch[6/100], Batch[1/600], batch_loss:2835.217773
# Epoch[6/100], Batch[101/600], batch_loss:2758.661133
# Epoch[6/100], Batch[201/600], batch_loss:3050.832031
# Epoch[6/100], Batch[301/600], batch_loss:2825.981445
# Epoch[6/100], Batch[401/600], batch_loss:2815.973145
# Epoch[6/100], Batch[501/600], batch_loss:2751.967041
# ======>epoch:6,	 epoch_average_batch_loss:2835.404424============
#
# Epoch[7/100], Batch[1/600], batch_loss:2817.261963
# Epoch[7/100], Batch[101/600], batch_loss:2876.499023
# Epoch[7/100], Batch[201/600], batch_loss:2935.956055
# Epoch[7/100], Batch[301/600], batch_loss:2763.743408
# Epoch[7/100], Batch[401/600], batch_loss:2869.692627
# Epoch[7/100], Batch[501/600], batch_loss:2905.874023
# ======>epoch:7,	 epoch_average_batch_loss:2798.927685============
#
# Epoch[8/100], Batch[1/600], batch_loss:2746.228271
# Epoch[8/100], Batch[101/600], batch_loss:2937.514160
# Epoch[8/100], Batch[201/600], batch_loss:2723.981934
# Epoch[8/100], Batch[301/600], batch_loss:2740.897217
# Epoch[8/100], Batch[401/600], batch_loss:2824.296631
# Epoch[8/100], Batch[501/600], batch_loss:2794.140137
# ======>epoch:8,	 epoch_average_batch_loss:2770.328376============
#
# Epoch[9/100], Batch[1/600], batch_loss:2634.497070
# Epoch[9/100], Batch[101/600], batch_loss:2727.087646
# Epoch[9/100], Batch[201/600], batch_loss:2897.809082
# Epoch[9/100], Batch[301/600], batch_loss:2911.151367
# Epoch[9/100], Batch[401/600], batch_loss:2786.492920
# Epoch[9/100], Batch[501/600], batch_loss:2661.313477
# ======>epoch:9,	 epoch_average_batch_loss:2745.202774============
#
# Epoch[10/100], Batch[1/600], batch_loss:2625.514160
# Epoch[10/100], Batch[101/600], batch_loss:2668.941406
# Epoch[10/100], Batch[201/600], batch_loss:2872.485840
# Epoch[10/100], Batch[301/600], batch_loss:2571.923340
# Epoch[10/100], Batch[401/600], batch_loss:2599.312012
# Epoch[10/100], Batch[501/600], batch_loss:2902.831299
# ======>epoch:10,	 epoch_average_batch_loss:2728.653973============
#
# Epoch[11/100], Batch[1/600], batch_loss:2581.780273
# Epoch[11/100], Batch[101/600], batch_loss:2687.509766
# Epoch[11/100], Batch[201/600], batch_loss:2589.306152
# Epoch[11/100], Batch[301/600], batch_loss:2748.719238
# Epoch[11/100], Batch[401/600], batch_loss:2780.751465
# Epoch[11/100], Batch[501/600], batch_loss:2690.523193
# ======>epoch:11,	 epoch_average_batch_loss:2709.641959============
#
# save: ./img/cvae/epoch11.png
#
# Epoch[12/100], Batch[1/600], batch_loss:2682.114990
# Epoch[12/100], Batch[101/600], batch_loss:2799.526367
# Epoch[12/100], Batch[201/600], batch_loss:2767.825439
# Epoch[12/100], Batch[301/600], batch_loss:2676.658203
# Epoch[12/100], Batch[401/600], batch_loss:2757.350586
# Epoch[12/100], Batch[501/600], batch_loss:2626.869629
# ======>epoch:12,	 epoch_average_batch_loss:2695.649143============
#
# Epoch[13/100], Batch[1/600], batch_loss:2677.490723
# Epoch[13/100], Batch[101/600], batch_loss:2527.402832
# Epoch[13/100], Batch[201/600], batch_loss:2794.193604
# Epoch[13/100], Batch[301/600], batch_loss:2601.468506
# Epoch[13/100], Batch[401/600], batch_loss:2549.221924
# Epoch[13/100], Batch[501/600], batch_loss:2689.376465
# ======>epoch:13,	 epoch_average_batch_loss:2684.368579============
#
# Epoch[14/100], Batch[1/600], batch_loss:2711.186035
# Epoch[14/100], Batch[101/600], batch_loss:2711.082520
# Epoch[14/100], Batch[201/600], batch_loss:2737.403320
# Epoch[14/100], Batch[301/600], batch_loss:2664.468750
# Epoch[14/100], Batch[401/600], batch_loss:2547.248047
# Epoch[14/100], Batch[501/600], batch_loss:2663.583496
# ======>epoch:14,	 epoch_average_batch_loss:2673.971522============
#
# Epoch[15/100], Batch[1/600], batch_loss:2672.951172
# Epoch[15/100], Batch[101/600], batch_loss:2604.761475
# Epoch[15/100], Batch[201/600], batch_loss:2658.043457
# Epoch[15/100], Batch[301/600], batch_loss:2699.963867
# Epoch[15/100], Batch[401/600], batch_loss:2841.841064
# Epoch[15/100], Batch[501/600], batch_loss:2607.968994
# ======>epoch:15,	 epoch_average_batch_loss:2663.125857============
#
# Epoch[16/100], Batch[1/600], batch_loss:2562.729736
# Epoch[16/100], Batch[101/600], batch_loss:2804.882568
# Epoch[16/100], Batch[201/600], batch_loss:2660.163818
# Epoch[16/100], Batch[301/600], batch_loss:2549.154541
# Epoch[16/100], Batch[401/600], batch_loss:2482.152832
# Epoch[16/100], Batch[501/600], batch_loss:2704.006592
# ======>epoch:16,	 epoch_average_batch_loss:2655.956880============
#
# Epoch[17/100], Batch[1/600], batch_loss:2639.687012
# Epoch[17/100], Batch[101/600], batch_loss:2705.174072
# Epoch[17/100], Batch[201/600], batch_loss:2645.242676
# Epoch[17/100], Batch[301/600], batch_loss:2789.940186
# Epoch[17/100], Batch[401/600], batch_loss:2550.864502
# Epoch[17/100], Batch[501/600], batch_loss:2554.537354
# ======>epoch:17,	 epoch_average_batch_loss:2647.303992============
#
# Epoch[18/100], Batch[1/600], batch_loss:2735.204590
# Epoch[18/100], Batch[101/600], batch_loss:2496.457275
# Epoch[18/100], Batch[201/600], batch_loss:2583.066406
# Epoch[18/100], Batch[301/600], batch_loss:2610.380127
# Epoch[18/100], Batch[401/600], batch_loss:2560.058105
# Epoch[18/100], Batch[501/600], batch_loss:2604.185059
# ======>epoch:18,	 epoch_average_batch_loss:2639.561873============
#
# Epoch[19/100], Batch[1/600], batch_loss:2748.575684
# Epoch[19/100], Batch[101/600], batch_loss:2711.291504
# Epoch[19/100], Batch[201/600], batch_loss:2792.701416
# Epoch[19/100], Batch[301/600], batch_loss:2518.298828
# Epoch[19/100], Batch[401/600], batch_loss:2527.150146
# Epoch[19/100], Batch[501/600], batch_loss:2724.894043
# ======>epoch:19,	 epoch_average_batch_loss:2632.563835============
#
# Epoch[20/100], Batch[1/600], batch_loss:2649.092773
# Epoch[20/100], Batch[101/600], batch_loss:2654.413818
# Epoch[20/100], Batch[201/600], batch_loss:2768.405762
# Epoch[20/100], Batch[301/600], batch_loss:2593.631104
# Epoch[20/100], Batch[401/600], batch_loss:2629.766846
# Epoch[20/100], Batch[501/600], batch_loss:2842.411133
# ======>epoch:20,	 epoch_average_batch_loss:2627.044107============
#
# Epoch[21/100], Batch[1/600], batch_loss:2592.803711
# Epoch[21/100], Batch[101/600], batch_loss:2518.461914
# Epoch[21/100], Batch[201/600], batch_loss:2858.186035
# Epoch[21/100], Batch[301/600], batch_loss:2530.172852
# Epoch[21/100], Batch[401/600], batch_loss:2764.848389
# Epoch[21/100], Batch[501/600], batch_loss:2720.001465
# ======>epoch:21,	 epoch_average_batch_loss:2618.594453============
#
# save: ./img/cvae/epoch21.png
#
# Epoch[22/100], Batch[1/600], batch_loss:2563.017090
# Epoch[22/100], Batch[101/600], batch_loss:2543.203369
# Epoch[22/100], Batch[201/600], batch_loss:2681.104492
# Epoch[22/100], Batch[301/600], batch_loss:2610.097412
# Epoch[22/100], Batch[401/600], batch_loss:2588.208008
# Epoch[22/100], Batch[501/600], batch_loss:2568.483154
# ======>epoch:22,	 epoch_average_batch_loss:2615.028664============
#
# Epoch[23/100], Batch[1/600], batch_loss:2541.851562
# Epoch[23/100], Batch[101/600], batch_loss:2783.531250
# Epoch[23/100], Batch[201/600], batch_loss:2547.830078
# Epoch[23/100], Batch[301/600], batch_loss:2627.608398
# Epoch[23/100], Batch[401/600], batch_loss:2708.033203
# Epoch[23/100], Batch[501/600], batch_loss:2593.077881
# ======>epoch:23,	 epoch_average_batch_loss:2609.716556============
#
# Epoch[24/100], Batch[1/600], batch_loss:2636.979248
# Epoch[24/100], Batch[101/600], batch_loss:2650.360107
# Epoch[24/100], Batch[201/600], batch_loss:2596.011230
# Epoch[24/100], Batch[301/600], batch_loss:2729.400391
# Epoch[24/100], Batch[401/600], batch_loss:2709.246582
# Epoch[24/100], Batch[501/600], batch_loss:2633.092773
# ======>epoch:24,	 epoch_average_batch_loss:2604.332969============
#
# Epoch[25/100], Batch[1/600], batch_loss:2392.679199
# Epoch[25/100], Batch[101/600], batch_loss:2685.898438
# Epoch[25/100], Batch[201/600], batch_loss:2510.689209
# Epoch[25/100], Batch[301/600], batch_loss:2342.314941
# Epoch[25/100], Batch[401/600], batch_loss:2433.514893
# Epoch[25/100], Batch[501/600], batch_loss:2523.235352
# ======>epoch:25,	 epoch_average_batch_loss:2598.892294============
#
# Epoch[26/100], Batch[1/600], batch_loss:2630.681885
# Epoch[26/100], Batch[101/600], batch_loss:2515.052490
# Epoch[26/100], Batch[201/600], batch_loss:2427.761230
# Epoch[26/100], Batch[301/600], batch_loss:2545.123535
# Epoch[26/100], Batch[401/600], batch_loss:2672.893066
# Epoch[26/100], Batch[501/600], batch_loss:2558.851562
# ======>epoch:26,	 epoch_average_batch_loss:2594.253632============
#
# Epoch[27/100], Batch[1/600], batch_loss:2689.675537
# Epoch[27/100], Batch[101/600], batch_loss:2576.180664
# Epoch[27/100], Batch[201/600], batch_loss:2586.221436
# Epoch[27/100], Batch[301/600], batch_loss:2577.258789
# Epoch[27/100], Batch[401/600], batch_loss:2467.981689
# Epoch[27/100], Batch[501/600], batch_loss:2560.630371
# ======>epoch:27,	 epoch_average_batch_loss:2591.391080============
#
# Epoch[28/100], Batch[1/600], batch_loss:2468.102051
# Epoch[28/100], Batch[101/600], batch_loss:2702.090088
# Epoch[28/100], Batch[201/600], batch_loss:2751.971924
# Epoch[28/100], Batch[301/600], batch_loss:2708.144531
# Epoch[28/100], Batch[401/600], batch_loss:2579.572998
# Epoch[28/100], Batch[501/600], batch_loss:2612.028809
# ======>epoch:28,	 epoch_average_batch_loss:2585.439019============
#
# Epoch[29/100], Batch[1/600], batch_loss:2466.970215
# Epoch[29/100], Batch[101/600], batch_loss:2572.037598
# Epoch[29/100], Batch[201/600], batch_loss:2517.441895
# Epoch[29/100], Batch[301/600], batch_loss:2471.834717
# Epoch[29/100], Batch[401/600], batch_loss:2495.705566
# Epoch[29/100], Batch[501/600], batch_loss:2671.501953
# ======>epoch:29,	 epoch_average_batch_loss:2583.530841============
#
# Epoch[30/100], Batch[1/600], batch_loss:2528.010986
# Epoch[30/100], Batch[101/600], batch_loss:2607.995361
# Epoch[30/100], Batch[201/600], batch_loss:2642.931152
# Epoch[30/100], Batch[301/600], batch_loss:2454.234863
# Epoch[30/100], Batch[401/600], batch_loss:2522.058350
# Epoch[30/100], Batch[501/600], batch_loss:2487.875488
# ======>epoch:30,	 epoch_average_batch_loss:2579.016884============
#
# Epoch[31/100], Batch[1/600], batch_loss:2500.932617
# Epoch[31/100], Batch[101/600], batch_loss:2568.560303
# Epoch[31/100], Batch[201/600], batch_loss:2517.519043
# Epoch[31/100], Batch[301/600], batch_loss:2594.485352
# Epoch[31/100], Batch[401/600], batch_loss:2723.823975
# Epoch[31/100], Batch[501/600], batch_loss:2527.982422
# ======>epoch:31,	 epoch_average_batch_loss:2574.375945============
#
# save: ./img/cvae/epoch31.png
#
# Epoch[32/100], Batch[1/600], batch_loss:2445.121826
# Epoch[32/100], Batch[101/600], batch_loss:2620.650635
# Epoch[32/100], Batch[201/600], batch_loss:2597.156006
# Epoch[32/100], Batch[301/600], batch_loss:2495.174316
# Epoch[32/100], Batch[401/600], batch_loss:2583.163818
# Epoch[32/100], Batch[501/600], batch_loss:2510.456299
# ======>epoch:32,	 epoch_average_batch_loss:2571.920855============
#
# Epoch[33/100], Batch[1/600], batch_loss:2702.376953
# Epoch[33/100], Batch[101/600], batch_loss:2646.449707
# Epoch[33/100], Batch[201/600], batch_loss:2569.365967
# Epoch[33/100], Batch[301/600], batch_loss:2541.876221
# Epoch[33/100], Batch[401/600], batch_loss:2607.059570
# Epoch[33/100], Batch[501/600], batch_loss:2388.315430
# ======>epoch:33,	 epoch_average_batch_loss:2568.270115============
#
# Epoch[34/100], Batch[1/600], batch_loss:2698.905029
# Epoch[34/100], Batch[101/600], batch_loss:2539.606934
# Epoch[34/100], Batch[201/600], batch_loss:2502.348145
# Epoch[34/100], Batch[301/600], batch_loss:2398.901123
# Epoch[34/100], Batch[401/600], batch_loss:2374.981934
# Epoch[34/100], Batch[501/600], batch_loss:2582.296875
# ======>epoch:34,	 epoch_average_batch_loss:2564.644301============
#
# Epoch[35/100], Batch[1/600], batch_loss:2582.049072
# Epoch[35/100], Batch[101/600], batch_loss:2531.758789
# Epoch[35/100], Batch[201/600], batch_loss:2527.316895
# Epoch[35/100], Batch[301/600], batch_loss:2503.271973
# Epoch[35/100], Batch[401/600], batch_loss:2668.885010
# Epoch[35/100], Batch[501/600], batch_loss:2473.558838
# ======>epoch:35,	 epoch_average_batch_loss:2562.366506============
#
# Epoch[36/100], Batch[1/600], batch_loss:2489.879395
# Epoch[36/100], Batch[101/600], batch_loss:2602.057617
# Epoch[36/100], Batch[201/600], batch_loss:2541.639160
# Epoch[36/100], Batch[301/600], batch_loss:2487.019043
# Epoch[36/100], Batch[401/600], batch_loss:2499.750488
# Epoch[36/100], Batch[501/600], batch_loss:2660.095215
# ======>epoch:36,	 epoch_average_batch_loss:2562.129886============
#
# Epoch[37/100], Batch[1/600], batch_loss:2494.832520
# Epoch[37/100], Batch[101/600], batch_loss:2515.076416
# Epoch[37/100], Batch[201/600], batch_loss:2665.621338
# Epoch[37/100], Batch[301/600], batch_loss:2412.160645
# Epoch[37/100], Batch[401/600], batch_loss:2598.248535
# Epoch[37/100], Batch[501/600], batch_loss:2521.344727
# ======>epoch:37,	 epoch_average_batch_loss:2556.766909============
#
# Epoch[38/100], Batch[1/600], batch_loss:2666.327637
# Epoch[38/100], Batch[101/600], batch_loss:2503.965088
# Epoch[38/100], Batch[201/600], batch_loss:2623.224609
# Epoch[38/100], Batch[301/600], batch_loss:2612.054688
# Epoch[38/100], Batch[401/600], batch_loss:2618.804199
# Epoch[38/100], Batch[501/600], batch_loss:2644.346924
# ======>epoch:38,	 epoch_average_batch_loss:2555.769795============
#
# Epoch[39/100], Batch[1/600], batch_loss:2575.785400
# Epoch[39/100], Batch[101/600], batch_loss:2526.587891
# Epoch[39/100], Batch[201/600], batch_loss:2529.090332
# Epoch[39/100], Batch[301/600], batch_loss:2534.842773
# Epoch[39/100], Batch[401/600], batch_loss:2445.065430
# Epoch[39/100], Batch[501/600], batch_loss:2398.846436
# ======>epoch:39,	 epoch_average_batch_loss:2550.633235============
#
# Epoch[40/100], Batch[1/600], batch_loss:2574.607910
# Epoch[40/100], Batch[101/600], batch_loss:2677.551270
# Epoch[40/100], Batch[201/600], batch_loss:2623.681641
# Epoch[40/100], Batch[301/600], batch_loss:2507.325684
# Epoch[40/100], Batch[401/600], batch_loss:2407.050293
# Epoch[40/100], Batch[501/600], batch_loss:2539.077148
# ======>epoch:40,	 epoch_average_batch_loss:2549.516837============
#
# Epoch[41/100], Batch[1/600], batch_loss:2449.401855
# Epoch[41/100], Batch[101/600], batch_loss:2509.026367
# Epoch[41/100], Batch[201/600], batch_loss:2617.225586
# Epoch[41/100], Batch[301/600], batch_loss:2376.694092
# Epoch[41/100], Batch[401/600], batch_loss:2434.237305
# Epoch[41/100], Batch[501/600], batch_loss:2543.555908
# ======>epoch:41,	 epoch_average_batch_loss:2547.177874============
#
# save: ./img/cvae/epoch41.png
#
# Epoch[42/100], Batch[1/600], batch_loss:2264.058105
# Epoch[42/100], Batch[101/600], batch_loss:2706.486816
# Epoch[42/100], Batch[201/600], batch_loss:2488.846680
# Epoch[42/100], Batch[301/600], batch_loss:2410.931641
# Epoch[42/100], Batch[401/600], batch_loss:2618.861816
# Epoch[42/100], Batch[501/600], batch_loss:2537.762695
# ======>epoch:42,	 epoch_average_batch_loss:2545.199252============
#
# Epoch[43/100], Batch[1/600], batch_loss:2592.671875
# Epoch[43/100], Batch[101/600], batch_loss:2482.059082
# Epoch[43/100], Batch[201/600], batch_loss:2669.822266
# Epoch[43/100], Batch[301/600], batch_loss:2613.946045
# Epoch[43/100], Batch[401/600], batch_loss:2467.316406
# Epoch[43/100], Batch[501/600], batch_loss:2468.005371
# ======>epoch:43,	 epoch_average_batch_loss:2541.706797============
#
# Epoch[44/100], Batch[1/600], batch_loss:2578.414795
# Epoch[44/100], Batch[101/600], batch_loss:2517.333252
# Epoch[44/100], Batch[201/600], batch_loss:2655.679443
# Epoch[44/100], Batch[301/600], batch_loss:2587.364746
# Epoch[44/100], Batch[401/600], batch_loss:2521.753418
# Epoch[44/100], Batch[501/600], batch_loss:2497.904541
# ======>epoch:44,	 epoch_average_batch_loss:2537.937802============
#
# Epoch[45/100], Batch[1/600], batch_loss:2539.924316
# Epoch[45/100], Batch[101/600], batch_loss:2561.958008
# Epoch[45/100], Batch[201/600], batch_loss:2514.437012
# Epoch[45/100], Batch[301/600], batch_loss:2579.514648
# Epoch[45/100], Batch[401/600], batch_loss:2677.023682
# Epoch[45/100], Batch[501/600], batch_loss:2592.429932
# ======>epoch:45,	 epoch_average_batch_loss:2536.871670============
#
# Epoch[46/100], Batch[1/600], batch_loss:2442.489746
# Epoch[46/100], Batch[101/600], batch_loss:2577.734619
# Epoch[46/100], Batch[201/600], batch_loss:2462.072754
# Epoch[46/100], Batch[301/600], batch_loss:2546.137695
# Epoch[46/100], Batch[401/600], batch_loss:2553.425049
# Epoch[46/100], Batch[501/600], batch_loss:2551.558350
# ======>epoch:46,	 epoch_average_batch_loss:2536.607795============
#
# Epoch[47/100], Batch[1/600], batch_loss:2477.600830
# Epoch[47/100], Batch[101/600], batch_loss:2429.990723
# Epoch[47/100], Batch[201/600], batch_loss:2471.519287
# Epoch[47/100], Batch[301/600], batch_loss:2449.365234
# Epoch[47/100], Batch[401/600], batch_loss:2489.620605
# Epoch[47/100], Batch[501/600], batch_loss:2582.018311
# ======>epoch:47,	 epoch_average_batch_loss:2535.412781============
#
# Epoch[48/100], Batch[1/600], batch_loss:2436.121826
# Epoch[48/100], Batch[101/600], batch_loss:2415.339111
# Epoch[48/100], Batch[201/600], batch_loss:2445.229980
# Epoch[48/100], Batch[301/600], batch_loss:2346.563965
# Epoch[48/100], Batch[401/600], batch_loss:2706.920410
# Epoch[48/100], Batch[501/600], batch_loss:2814.471191
# ======>epoch:48,	 epoch_average_batch_loss:2532.515520============
#
# Epoch[49/100], Batch[1/600], batch_loss:2464.389893
# Epoch[49/100], Batch[101/600], batch_loss:2539.442139
# Epoch[49/100], Batch[201/600], batch_loss:2621.863037
# Epoch[49/100], Batch[301/600], batch_loss:2452.024658
# Epoch[49/100], Batch[401/600], batch_loss:2613.153320
# Epoch[49/100], Batch[501/600], batch_loss:2477.293457
# ======>epoch:49,	 epoch_average_batch_loss:2531.589289============
#
# Epoch[50/100], Batch[1/600], batch_loss:2511.994141
# Epoch[50/100], Batch[101/600], batch_loss:2642.194824
# Epoch[50/100], Batch[201/600], batch_loss:2512.757324
# Epoch[50/100], Batch[301/600], batch_loss:2508.268555
# Epoch[50/100], Batch[401/600], batch_loss:2532.502441
# Epoch[50/100], Batch[501/600], batch_loss:2553.054932
# ======>epoch:50,	 epoch_average_batch_loss:2531.330167============
#
# Epoch[51/100], Batch[1/600], batch_loss:2570.445312
# Epoch[51/100], Batch[101/600], batch_loss:2583.587891
# Epoch[51/100], Batch[201/600], batch_loss:2583.431152
# Epoch[51/100], Batch[301/600], batch_loss:2421.721191
# Epoch[51/100], Batch[401/600], batch_loss:2611.671875
# Epoch[51/100], Batch[501/600], batch_loss:2459.885254
# ======>epoch:51,	 epoch_average_batch_loss:2528.724055============
#
# save: ./img/cvae/epoch51.png
#
# Epoch[52/100], Batch[1/600], batch_loss:2590.148926
# Epoch[52/100], Batch[101/600], batch_loss:2292.927734
# Epoch[52/100], Batch[201/600], batch_loss:2377.168457
# Epoch[52/100], Batch[301/600], batch_loss:2532.807861
# Epoch[52/100], Batch[401/600], batch_loss:2487.810303
# Epoch[52/100], Batch[501/600], batch_loss:2652.012695
# ======>epoch:52,	 epoch_average_batch_loss:2525.811932============
#
# Epoch[53/100], Batch[1/600], batch_loss:2565.026367
# Epoch[53/100], Batch[101/600], batch_loss:2505.581543
# Epoch[53/100], Batch[201/600], batch_loss:2515.917480
# Epoch[53/100], Batch[301/600], batch_loss:2595.012451
# Epoch[53/100], Batch[401/600], batch_loss:2472.770508
# Epoch[53/100], Batch[501/600], batch_loss:2505.255859
# ======>epoch:53,	 epoch_average_batch_loss:2524.658665============
#
# Epoch[54/100], Batch[1/600], batch_loss:2673.214111
# Epoch[54/100], Batch[101/600], batch_loss:2483.919922
# Epoch[54/100], Batch[201/600], batch_loss:2546.708496
# Epoch[54/100], Batch[301/600], batch_loss:2490.603271
# Epoch[54/100], Batch[401/600], batch_loss:2663.160645
# Epoch[54/100], Batch[501/600], batch_loss:2471.380859
# ======>epoch:54,	 epoch_average_batch_loss:2523.011177============
#
# Epoch[55/100], Batch[1/600], batch_loss:2569.009766
# Epoch[55/100], Batch[101/600], batch_loss:2471.484619
# Epoch[55/100], Batch[201/600], batch_loss:2624.298340
# Epoch[55/100], Batch[301/600], batch_loss:2508.615723
# Epoch[55/100], Batch[401/600], batch_loss:2609.086426
# Epoch[55/100], Batch[501/600], batch_loss:2368.532227
# ======>epoch:55,	 epoch_average_batch_loss:2521.351119============
#
# Epoch[56/100], Batch[1/600], batch_loss:2548.694336
# Epoch[56/100], Batch[101/600], batch_loss:2505.507324
# Epoch[56/100], Batch[201/600], batch_loss:2496.045166
# Epoch[56/100], Batch[301/600], batch_loss:2480.979980
# Epoch[56/100], Batch[401/600], batch_loss:2592.678223
# Epoch[56/100], Batch[501/600], batch_loss:2603.046387
# ======>epoch:56,	 epoch_average_batch_loss:2520.289327============
#
# Epoch[57/100], Batch[1/600], batch_loss:2431.403320
# Epoch[57/100], Batch[101/600], batch_loss:2602.456543
# Epoch[57/100], Batch[201/600], batch_loss:2695.035889
# Epoch[57/100], Batch[301/600], batch_loss:2592.560547
# Epoch[57/100], Batch[401/600], batch_loss:2480.141602
# Epoch[57/100], Batch[501/600], batch_loss:2632.728760
# ======>epoch:57,	 epoch_average_batch_loss:2520.525691============
#
# Epoch[58/100], Batch[1/600], batch_loss:2649.687988
# Epoch[58/100], Batch[101/600], batch_loss:2368.127441
# Epoch[58/100], Batch[201/600], batch_loss:2441.219971
# Epoch[58/100], Batch[301/600], batch_loss:2587.650635
# Epoch[58/100], Batch[401/600], batch_loss:2392.396729
# Epoch[58/100], Batch[501/600], batch_loss:2517.185547
# ======>epoch:58,	 epoch_average_batch_loss:2516.893387============
#
# Epoch[59/100], Batch[1/600], batch_loss:2518.937988
# Epoch[59/100], Batch[101/600], batch_loss:2499.788086
# Epoch[59/100], Batch[201/600], batch_loss:2508.236816
# Epoch[59/100], Batch[301/600], batch_loss:2484.599609
# Epoch[59/100], Batch[401/600], batch_loss:2622.167236
# Epoch[59/100], Batch[501/600], batch_loss:2563.056396
# ======>epoch:59,	 epoch_average_batch_loss:2516.156981============
#
# Epoch[60/100], Batch[1/600], batch_loss:2637.120117
# Epoch[60/100], Batch[101/600], batch_loss:2477.519531
# Epoch[60/100], Batch[201/600], batch_loss:2631.030029
# Epoch[60/100], Batch[301/600], batch_loss:2499.083740
# Epoch[60/100], Batch[401/600], batch_loss:2661.748535
# Epoch[60/100], Batch[501/600], batch_loss:2402.158691
# ======>epoch:60,	 epoch_average_batch_loss:2516.425667============
#
# Epoch[61/100], Batch[1/600], batch_loss:2640.046875
# Epoch[61/100], Batch[101/600], batch_loss:2831.046143
# Epoch[61/100], Batch[201/600], batch_loss:2453.473633
# Epoch[61/100], Batch[301/600], batch_loss:2550.256348
# Epoch[61/100], Batch[401/600], batch_loss:2522.766602
# Epoch[61/100], Batch[501/600], batch_loss:2440.904785
# ======>epoch:61,	 epoch_average_batch_loss:2513.903219============
#
# save: ./img/cvae/epoch61.png
#
# Epoch[62/100], Batch[1/600], batch_loss:2505.470215
# Epoch[62/100], Batch[101/600], batch_loss:2507.845459
# Epoch[62/100], Batch[201/600], batch_loss:2459.610352
# Epoch[62/100], Batch[301/600], batch_loss:2403.010742
# Epoch[62/100], Batch[401/600], batch_loss:2559.001709
# Epoch[62/100], Batch[501/600], batch_loss:2525.661133
# ======>epoch:62,	 epoch_average_batch_loss:2512.129974============
#
# Epoch[63/100], Batch[1/600], batch_loss:2638.520508
# Epoch[63/100], Batch[101/600], batch_loss:2682.100586
# Epoch[63/100], Batch[201/600], batch_loss:2687.434082
# Epoch[63/100], Batch[301/600], batch_loss:2519.707275
# Epoch[63/100], Batch[401/600], batch_loss:2529.843750
# Epoch[63/100], Batch[501/600], batch_loss:2522.961426
# ======>epoch:63,	 epoch_average_batch_loss:2513.050975============
#
# Epoch[64/100], Batch[1/600], batch_loss:2627.421387
# Epoch[64/100], Batch[101/600], batch_loss:2569.509766
# Epoch[64/100], Batch[201/600], batch_loss:2577.547852
# Epoch[64/100], Batch[301/600], batch_loss:2426.035156
# Epoch[64/100], Batch[401/600], batch_loss:2532.078613
# Epoch[64/100], Batch[501/600], batch_loss:2607.773682
# ======>epoch:64,	 epoch_average_batch_loss:2510.488465============
#
# Epoch[65/100], Batch[1/600], batch_loss:2513.113770
# Epoch[65/100], Batch[101/600], batch_loss:2494.582520
# Epoch[65/100], Batch[201/600], batch_loss:2619.777588
# Epoch[65/100], Batch[301/600], batch_loss:2507.804199
# Epoch[65/100], Batch[401/600], batch_loss:2659.488770
# Epoch[65/100], Batch[501/600], batch_loss:2424.625977
# ======>epoch:65,	 epoch_average_batch_loss:2509.485962============
#
# Epoch[66/100], Batch[1/600], batch_loss:2641.286133
# Epoch[66/100], Batch[101/600], batch_loss:2386.102051
# Epoch[66/100], Batch[201/600], batch_loss:2422.786865
# Epoch[66/100], Batch[301/600], batch_loss:2454.578613
# Epoch[66/100], Batch[401/600], batch_loss:2624.010986
# Epoch[66/100], Batch[501/600], batch_loss:2487.980957
# ======>epoch:66,	 epoch_average_batch_loss:2506.214146============
#
# Epoch[67/100], Batch[1/600], batch_loss:2521.320312
# Epoch[67/100], Batch[101/600], batch_loss:2506.411865
# Epoch[67/100], Batch[201/600], batch_loss:2593.520752
# Epoch[67/100], Batch[301/600], batch_loss:2500.429688
# Epoch[67/100], Batch[401/600], batch_loss:2552.378662
# Epoch[67/100], Batch[501/600], batch_loss:2689.824219
# ======>epoch:67,	 epoch_average_batch_loss:2507.324517============
#
# Epoch[68/100], Batch[1/600], batch_loss:2476.499756
# Epoch[68/100], Batch[101/600], batch_loss:2518.575684
# Epoch[68/100], Batch[201/600], batch_loss:2596.658691
# Epoch[68/100], Batch[301/600], batch_loss:2452.468018
# Epoch[68/100], Batch[401/600], batch_loss:2445.792236
# Epoch[68/100], Batch[501/600], batch_loss:2586.699707
# ======>epoch:68,	 epoch_average_batch_loss:2504.594588============
#
# Epoch[69/100], Batch[1/600], batch_loss:2298.793457
# Epoch[69/100], Batch[101/600], batch_loss:2466.134766
# Epoch[69/100], Batch[201/600], batch_loss:2432.243164
# Epoch[69/100], Batch[301/600], batch_loss:2477.342529
# Epoch[69/100], Batch[401/600], batch_loss:2658.791016
# Epoch[69/100], Batch[501/600], batch_loss:2489.293457
# ======>epoch:69,	 epoch_average_batch_loss:2503.378044============
#
# Epoch[70/100], Batch[1/600], batch_loss:2412.162109
# Epoch[70/100], Batch[101/600], batch_loss:2394.927002
# Epoch[70/100], Batch[201/600], batch_loss:2567.405518
# Epoch[70/100], Batch[301/600], batch_loss:2415.670410
# Epoch[70/100], Batch[401/600], batch_loss:2320.885254
# Epoch[70/100], Batch[501/600], batch_loss:2429.703613
# ======>epoch:70,	 epoch_average_batch_loss:2504.041907============
#
# Epoch[71/100], Batch[1/600], batch_loss:2601.611328
# Epoch[71/100], Batch[101/600], batch_loss:2560.125977
# Epoch[71/100], Batch[201/600], batch_loss:2546.298340
# Epoch[71/100], Batch[301/600], batch_loss:2488.639893
# Epoch[71/100], Batch[401/600], batch_loss:2434.946777
# Epoch[71/100], Batch[501/600], batch_loss:2462.189697
# ======>epoch:71,	 epoch_average_batch_loss:2502.855594============
#
# save: ./img/cvae/epoch71.png
#
# Epoch[72/100], Batch[1/600], batch_loss:2494.771240
# Epoch[72/100], Batch[101/600], batch_loss:2351.708496
# Epoch[72/100], Batch[201/600], batch_loss:2414.003906
# Epoch[72/100], Batch[301/600], batch_loss:2425.828125
# Epoch[72/100], Batch[401/600], batch_loss:2464.108887
# Epoch[72/100], Batch[501/600], batch_loss:2544.345947
# ======>epoch:72,	 epoch_average_batch_loss:2501.825126============
#
# Epoch[73/100], Batch[1/600], batch_loss:2661.592529
# Epoch[73/100], Batch[101/600], batch_loss:2564.940430
# Epoch[73/100], Batch[201/600], batch_loss:2400.824219
# Epoch[73/100], Batch[301/600], batch_loss:2362.825928
# Epoch[73/100], Batch[401/600], batch_loss:2521.473877
# Epoch[73/100], Batch[501/600], batch_loss:2234.884766
# ======>epoch:73,	 epoch_average_batch_loss:2498.365835============
#
# Epoch[74/100], Batch[1/600], batch_loss:2398.301270
# Epoch[74/100], Batch[101/600], batch_loss:2488.449463
# Epoch[74/100], Batch[201/600], batch_loss:2587.713867
# Epoch[74/100], Batch[301/600], batch_loss:2486.879883
# Epoch[74/100], Batch[401/600], batch_loss:2432.709961
# Epoch[74/100], Batch[501/600], batch_loss:2592.956055
# ======>epoch:74,	 epoch_average_batch_loss:2500.994987============
#
# Epoch[75/100], Batch[1/600], batch_loss:2554.735840
# Epoch[75/100], Batch[101/600], batch_loss:2453.368896
# Epoch[75/100], Batch[201/600], batch_loss:2622.788086
# Epoch[75/100], Batch[301/600], batch_loss:2555.954102
# Epoch[75/100], Batch[401/600], batch_loss:2537.993896
# Epoch[75/100], Batch[501/600], batch_loss:2596.665039
# ======>epoch:75,	 epoch_average_batch_loss:2499.717978============
#
# Epoch[76/100], Batch[1/600], batch_loss:2434.769775
# Epoch[76/100], Batch[101/600], batch_loss:2445.276367
# Epoch[76/100], Batch[201/600], batch_loss:2515.894043
# Epoch[76/100], Batch[301/600], batch_loss:2624.293701
# Epoch[76/100], Batch[401/600], batch_loss:2598.093506
# Epoch[76/100], Batch[501/600], batch_loss:2508.788818
# ======>epoch:76,	 epoch_average_batch_loss:2497.189530============
#
# Epoch[77/100], Batch[1/600], batch_loss:2648.504395
# Epoch[77/100], Batch[101/600], batch_loss:2445.788574
# Epoch[77/100], Batch[201/600], batch_loss:2479.014404
# Epoch[77/100], Batch[301/600], batch_loss:2415.474609
# Epoch[77/100], Batch[401/600], batch_loss:2475.241943
# Epoch[77/100], Batch[501/600], batch_loss:2489.876709
# ======>epoch:77,	 epoch_average_batch_loss:2497.030411============
#
# Epoch[78/100], Batch[1/600], batch_loss:2437.651855
# Epoch[78/100], Batch[101/600], batch_loss:2437.596436
# Epoch[78/100], Batch[201/600], batch_loss:2422.137695
# Epoch[78/100], Batch[301/600], batch_loss:2426.368896
# Epoch[78/100], Batch[401/600], batch_loss:2557.641357
# Epoch[78/100], Batch[501/600], batch_loss:2624.776855
# ======>epoch:78,	 epoch_average_batch_loss:2496.417914============
#
# Epoch[79/100], Batch[1/600], batch_loss:2472.865234
# Epoch[79/100], Batch[101/600], batch_loss:2440.907959
# Epoch[79/100], Batch[201/600], batch_loss:2493.514160
# Epoch[79/100], Batch[301/600], batch_loss:2611.332520
# Epoch[79/100], Batch[401/600], batch_loss:2461.091553
# Epoch[79/100], Batch[501/600], batch_loss:2486.937988
# ======>epoch:79,	 epoch_average_batch_loss:2495.335960============
#
# Epoch[80/100], Batch[1/600], batch_loss:2506.619629
# Epoch[80/100], Batch[101/600], batch_loss:2471.901367
# Epoch[80/100], Batch[201/600], batch_loss:2422.188232
# Epoch[80/100], Batch[301/600], batch_loss:2572.851074
# Epoch[80/100], Batch[401/600], batch_loss:2558.833008
# Epoch[80/100], Batch[501/600], batch_loss:2634.796631
# ======>epoch:80,	 epoch_average_batch_loss:2493.582495============
#
# Epoch[81/100], Batch[1/600], batch_loss:2372.462158
# Epoch[81/100], Batch[101/600], batch_loss:2615.432861
# Epoch[81/100], Batch[201/600], batch_loss:2509.660645
# Epoch[81/100], Batch[301/600], batch_loss:2362.651855
# Epoch[81/100], Batch[401/600], batch_loss:2506.329590
# Epoch[81/100], Batch[501/600], batch_loss:2449.791992
# ======>epoch:81,	 epoch_average_batch_loss:2494.163575============
#
# save: ./img/cvae/epoch81.png
#
# Epoch[82/100], Batch[1/600], batch_loss:2620.320801
# Epoch[82/100], Batch[101/600], batch_loss:2410.968750
# Epoch[82/100], Batch[201/600], batch_loss:2650.116943
# Epoch[82/100], Batch[301/600], batch_loss:2513.076172
# Epoch[82/100], Batch[401/600], batch_loss:2494.168945
# Epoch[82/100], Batch[501/600], batch_loss:2450.040527
# ======>epoch:82,	 epoch_average_batch_loss:2492.403460============
#
# Epoch[83/100], Batch[1/600], batch_loss:2643.490479
# Epoch[83/100], Batch[101/600], batch_loss:2466.835449
# Epoch[83/100], Batch[201/600], batch_loss:2625.435303
# Epoch[83/100], Batch[301/600], batch_loss:2341.803955
# Epoch[83/100], Batch[401/600], batch_loss:2582.068115
# Epoch[83/100], Batch[501/600], batch_loss:2642.411865
# ======>epoch:83,	 epoch_average_batch_loss:2495.098175============
#
# Epoch[84/100], Batch[1/600], batch_loss:2441.866943
# Epoch[84/100], Batch[101/600], batch_loss:2494.690186
# Epoch[84/100], Batch[201/600], batch_loss:2491.729492
# Epoch[84/100], Batch[301/600], batch_loss:2376.936768
# Epoch[84/100], Batch[401/600], batch_loss:2456.271484
# Epoch[84/100], Batch[501/600], batch_loss:2396.458984
# ======>epoch:84,	 epoch_average_batch_loss:2493.434943============
#
# Epoch[85/100], Batch[1/600], batch_loss:2314.526367
# Epoch[85/100], Batch[101/600], batch_loss:2525.983643
# Epoch[85/100], Batch[201/600], batch_loss:2432.734375
# Epoch[85/100], Batch[301/600], batch_loss:2427.436279
# Epoch[85/100], Batch[401/600], batch_loss:2422.013672
# Epoch[85/100], Batch[501/600], batch_loss:2525.189697
# ======>epoch:85,	 epoch_average_batch_loss:2490.047912============
#
# Epoch[86/100], Batch[1/600], batch_loss:2492.343262
# Epoch[86/100], Batch[101/600], batch_loss:2474.110352
# Epoch[86/100], Batch[201/600], batch_loss:2535.190918
# Epoch[86/100], Batch[301/600], batch_loss:2397.618164
# Epoch[86/100], Batch[401/600], batch_loss:2230.902344
# Epoch[86/100], Batch[501/600], batch_loss:2423.868896
# ======>epoch:86,	 epoch_average_batch_loss:2489.431383============
#
# Epoch[87/100], Batch[1/600], batch_loss:2425.248535
# Epoch[87/100], Batch[101/600], batch_loss:2419.589844
# Epoch[87/100], Batch[201/600], batch_loss:2584.571045
# Epoch[87/100], Batch[301/600], batch_loss:2267.008545
# Epoch[87/100], Batch[401/600], batch_loss:2508.751465
# Epoch[87/100], Batch[501/600], batch_loss:2521.940918
# ======>epoch:87,	 epoch_average_batch_loss:2490.858300============
#
# Epoch[88/100], Batch[1/600], batch_loss:2582.829102
# Epoch[88/100], Batch[101/600], batch_loss:2365.054688
# Epoch[88/100], Batch[201/600], batch_loss:2421.753418
# Epoch[88/100], Batch[301/600], batch_loss:2623.683594
# Epoch[88/100], Batch[401/600], batch_loss:2456.340576
# Epoch[88/100], Batch[501/600], batch_loss:2491.997559
# ======>epoch:88,	 epoch_average_batch_loss:2488.772411============
#
# Epoch[89/100], Batch[1/600], batch_loss:2355.238281
# Epoch[89/100], Batch[101/600], batch_loss:2397.874512
# Epoch[89/100], Batch[201/600], batch_loss:2458.990723
# Epoch[89/100], Batch[301/600], batch_loss:2496.069336
# Epoch[89/100], Batch[401/600], batch_loss:2537.021729
# Epoch[89/100], Batch[501/600], batch_loss:2516.999756
# ======>epoch:89,	 epoch_average_batch_loss:2489.178087============
#
# Epoch[90/100], Batch[1/600], batch_loss:2311.612061
# Epoch[90/100], Batch[101/600], batch_loss:2339.941162
# Epoch[90/100], Batch[201/600], batch_loss:2516.316895
# Epoch[90/100], Batch[301/600], batch_loss:2465.147949
# Epoch[90/100], Batch[401/600], batch_loss:2550.265381
# Epoch[90/100], Batch[501/600], batch_loss:2554.906738
# ======>epoch:90,	 epoch_average_batch_loss:2487.222593============
#
# Epoch[91/100], Batch[1/600], batch_loss:2403.565918
# Epoch[91/100], Batch[101/600], batch_loss:2419.970215
# Epoch[91/100], Batch[201/600], batch_loss:2633.448242
# Epoch[91/100], Batch[301/600], batch_loss:2392.185059
# Epoch[91/100], Batch[401/600], batch_loss:2509.389404
# Epoch[91/100], Batch[501/600], batch_loss:2462.616455
# ======>epoch:91,	 epoch_average_batch_loss:2486.456472============
#
# save: ./img/cvae/epoch91.png
#
# Epoch[92/100], Batch[1/600], batch_loss:2517.124512
# Epoch[92/100], Batch[101/600], batch_loss:2556.907227
# Epoch[92/100], Batch[201/600], batch_loss:2530.770508
# Epoch[92/100], Batch[301/600], batch_loss:2550.276855
# Epoch[92/100], Batch[401/600], batch_loss:2587.650635
# Epoch[92/100], Batch[501/600], batch_loss:2485.280029
# ======>epoch:92,	 epoch_average_batch_loss:2486.149510============
#
# Epoch[93/100], Batch[1/600], batch_loss:2417.327637
# Epoch[93/100], Batch[101/600], batch_loss:2560.090820
# Epoch[93/100], Batch[201/600], batch_loss:2375.665771
# Epoch[93/100], Batch[301/600], batch_loss:2587.963867
# Epoch[93/100], Batch[401/600], batch_loss:2538.413086
# Epoch[93/100], Batch[501/600], batch_loss:2588.256348
# ======>epoch:93,	 epoch_average_batch_loss:2483.802159============
#
# Epoch[94/100], Batch[1/600], batch_loss:2524.659180
# Epoch[94/100], Batch[101/600], batch_loss:2533.103027
# Epoch[94/100], Batch[201/600], batch_loss:2477.331787
# Epoch[94/100], Batch[301/600], batch_loss:2531.807861
# Epoch[94/100], Batch[401/600], batch_loss:2476.026367
# Epoch[94/100], Batch[501/600], batch_loss:2549.887695
# ======>epoch:94,	 epoch_average_batch_loss:2486.228161============
#
# Epoch[95/100], Batch[1/600], batch_loss:2467.243896
# Epoch[95/100], Batch[101/600], batch_loss:2534.539062
# Epoch[95/100], Batch[201/600], batch_loss:2592.974365
# Epoch[95/100], Batch[301/600], batch_loss:2483.959229
# Epoch[95/100], Batch[401/600], batch_loss:2411.034668
# Epoch[95/100], Batch[501/600], batch_loss:2613.780762
# ======>epoch:95,	 epoch_average_batch_loss:2483.105111============
#
# Epoch[96/100], Batch[1/600], batch_loss:2531.429443
# Epoch[96/100], Batch[101/600], batch_loss:2328.528809
# Epoch[96/100], Batch[201/600], batch_loss:2260.478760
# Epoch[96/100], Batch[301/600], batch_loss:2511.639160
# Epoch[96/100], Batch[401/600], batch_loss:2374.084473
# Epoch[96/100], Batch[501/600], batch_loss:2528.470215
# ======>epoch:96,	 epoch_average_batch_loss:2482.931383============
#
# Epoch[97/100], Batch[1/600], batch_loss:2413.815430
# Epoch[97/100], Batch[101/600], batch_loss:2491.238281
# Epoch[97/100], Batch[201/600], batch_loss:2576.771484
# Epoch[97/100], Batch[301/600], batch_loss:2486.473633
# Epoch[97/100], Batch[401/600], batch_loss:2611.495361
# Epoch[97/100], Batch[501/600], batch_loss:2443.858887
# ======>epoch:97,	 epoch_average_batch_loss:2482.712058============
#
# Epoch[98/100], Batch[1/600], batch_loss:2613.398438
# Epoch[98/100], Batch[101/600], batch_loss:2588.065430
# Epoch[98/100], Batch[201/600], batch_loss:2551.536621
# Epoch[98/100], Batch[301/600], batch_loss:2609.703613
# Epoch[98/100], Batch[401/600], batch_loss:2558.717529
# Epoch[98/100], Batch[501/600], batch_loss:2324.087646
# ======>epoch:98,	 epoch_average_batch_loss:2483.716394============
#
# Epoch[99/100], Batch[1/600], batch_loss:2600.450928
# Epoch[99/100], Batch[101/600], batch_loss:2633.627930
# Epoch[99/100], Batch[201/600], batch_loss:2354.242188
# Epoch[99/100], Batch[301/600], batch_loss:2266.317627
# Epoch[99/100], Batch[401/600], batch_loss:2638.049316
# Epoch[99/100], Batch[501/600], batch_loss:2564.028809
# ======>epoch:99,	 epoch_average_batch_loss:2481.573378============
#
# Epoch[100/100], Batch[1/600], batch_loss:2536.514648
# Epoch[100/100], Batch[101/600], batch_loss:2508.881348
# Epoch[100/100], Batch[201/600], batch_loss:2566.022949
# Epoch[100/100], Batch[301/600], batch_loss:2386.964355
# Epoch[100/100], Batch[401/600], batch_loss:2426.843750
# Epoch[100/100], Batch[501/600], batch_loss:2401.033691
# ======>epoch:100,	 epoch_average_batch_loss:2479.922793============
#
# save raw image:./img/cvae/raw/png
#
# save model..........

# %%
import torch

tensorz = torch.randn(4)  # 假设tensorz是大小为[4]的张量

print(tensorz)
tensor = tensorz.view(1, 4)  # 使用view函数将张量大小转换为[1, 4]
print(tensor)
print(tensor.size())  # 打印转换后张量的大小
# Out:
# tensor([ 0.6743,  0.1043, -0.8124,  0.4877])
# tensor([[ 0.6743,  0.1043, -0.8124,  0.4877]])
# torch.Size([1, 4])
